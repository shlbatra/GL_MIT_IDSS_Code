# %% [markdown]
# # **MLS Case Study - Neural Networks**

# %% [markdown]
# ### **Context:**
#
# The world is developing rapidly and continuously looking for the best knowledge and experience among people. This motivates people all around the world to stand out in their jobs and look for higher degrees that can help them in improving their skills and knowledge. As a result, the number of students applying for Master's programs has increased substantially.
#
# The current admission dataset was created for the prediction of admissions into the University of California, Los Angeles (UCLA). It was built to help students in shortlisting universities based on their profiles. The predicted output gives them a fair idea about their chances of getting accepted.

# %% [markdown]
# ### **Objective:**
#
# We need to build a classification model using neural networks to predict a student's chances of admission into UCLA.

# %% [markdown]
# ### **Data Dictionary:**
#
# The dataset contains several parameters which are considered important during the application for Masters Programs.
# The parameters included are :
#
# **GRE Scores:** (out of 340) \
# **TOEFL Scores:** (out of 120) \
# **University Rating:**  It indicates the Bachelor University ranking (out of 5) \
# **Statement of Purpose Strength:** (out of 5) \
# **Letter of Recommendation Strength:** (out of 5) \
# **Undergraduate GPA:** (out of 10) \
# **Research Experience:** (either 0 or 1) \
# **Chance of Admit:** (ranging from 0 to 1) \

# %% [markdown]
# ### **Loading the libraries and the dataset**

# %% [markdown]
# First, let's import the data into the drive so that Colab can access the dataset. One way to load the data In Colab is by mounting the drive. into the drive from your local system is to use the following code.
# Once you run the cell, it would ask you to choose the file from your local system.

# %%
#from google.colab import files
#uploaded = files.upload()
# Out:
#      <input type="file" id="files-6673f108-2f9e-4449-be4f-7dc5284eed5f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-6673f108-2f9e-4449-be4f-7dc5284eed5f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Admission_Predict.csv to Admission_Predict.csv

# %%
# !pip install -U keras-tuner

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Activation
from kerastuner.tuners import RandomSearch
from tensorflow.keras import optimizers
from keras.utils.vis_utils import plot_model

# %% [markdown]
# Now, let's load the data using the read_csv() function. One small change from Jupyter here is that the path of the file might be a bit different.
# To get the path of the data file, follow the below steps:
# - To go the panel on the left-hand side and click on the folder icon at the bottom
# - Move the cursor on the file name
# - Click on the three dots and select the option "Copy path"

# %%
print(tf.__version__)
# Out:
# 2.7.0

# %%
#Set up your google drive as mount to read/write files
from google.colab import drive

# %%
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
#Would change based on your local google drive structure
project_path = '/content/drive/MyDrive/GL_MIT/'

# %%
data = pd.read_csv(project_path + 'Admission_Predict.csv')
data.head()
# Out:
#    Serial No.  GRE Score  TOEFL Score  ...  CGPA  Research  Chance of Admit
# 0           1        337          118  ...  9.65         1              0.92
# 1           2        324          107  ...  8.87         1              0.76
# 2           3        316          104  ...  8.00         1              0.72
# 3           4        322          110  ...  8.67         1              0.80
# 4           5        314          103  ...  8.21         0              0.65
#
# [5 rows x 9 columns]

# %% [markdown]
# - In the above dataset, the target variable is **Chance of Admit**
# - To make this a classification task, let's convert the target variable into a categorical variable by using a threshold of 80%
# - We are assuming that if **Chance of Admit** is more than 80% then **Admit** would be 1 (i.e. yes) otherwise it would be 0 (i.e. no)

# %%
#Converting the target variable into a categorical variable
data['Admit'] = data['Chance of Admit '].apply(lambda x: 1 if x > 0.8 else 0)

# Convert Prediction problem to Classification problem

# %% [markdown]
# Now that we have created new a target variable, we can remove the column - **Chance of Admit** from the dataset. We can also remove the column - **Serial No.** as it would not add any value to our analysis.

# %%
#Dropping columns
data = data.drop(['Serial No.', 'Chance of Admit '], axis=1)
data.head()
# Out:
#    GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  Research  Admit
# 0        337          118                  4  4.5   4.5  9.65         1      1
# 1        324          107                  4  4.0   4.5  8.87         1      0
# 2        316          104                  3  3.0   3.5  8.00         1      0
# 3        322          110                  3  3.5   2.5  8.67         1      0
# 4        314          103                  2  2.0   3.0  8.21         0      0

# %% [markdown]
# Let's check the info of the data

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   GRE Score          500 non-null    int64
#  1   TOEFL Score        500 non-null    int64
#  2   University Rating  500 non-null    int64
#  3   SOP                500 non-null    float64
#  4   LOR                500 non-null    float64
#  5   CGPA               500 non-null    float64
#  6   Research           500 non-null    int64
#  7   Admit              500 non-null    int64
# dtypes: float64(3), int64(5)
# memory usage: 31.4 KB

# %% [markdown]
# **Observations:**
#
# - There are **500 observations and 8 columns** in the data
# - All the columns are of **numeric data** type
# - There are **no missing values** in the data

# %% [markdown]
# Let's check the summary statistics of the data

# %%
data.describe().T
# Out:
#                    count       mean        std  ...     50%     75%     max
# GRE Score          500.0  316.47200  11.295148  ...  317.00  325.00  340.00
# TOEFL Score        500.0  107.19200   6.081868  ...  107.00  112.00  120.00
# University Rating  500.0    3.11400   1.143512  ...    3.00    4.00    5.00
# SOP                500.0    3.37400   0.991004  ...    3.50    4.00    5.00
# LOR                500.0    3.48400   0.925450  ...    3.50    4.00    5.00
# CGPA               500.0    8.57644   0.604813  ...    8.56    9.04    9.92
# Research           500.0    0.56000   0.496884  ...    1.00    1.00    1.00
# Admit              500.0    0.28400   0.451388  ...    0.00    1.00    1.00
#
# [8 rows x 8 columns]

# %%
### Univariate Plot

# %%
#creating histograms
for i in data.columns:
    print(i)
    print('Skew :',round(data[i].skew(),2))
    print('Kurt :',round(data[i].kurt(),2))
    plt.figure(figsize=(15,4))
    plt.subplot(1,2,1)
    data[i].hist(bins=10, grid=False)
    plt.subplot(1,2,2)
    sns.boxplot(x=data[i])
    plt.show()
# Out:
# GRE Score
# Skew : -0.04
# Kurt : -0.71
# TOEFL Score
# Skew : 0.1
# Kurt : -0.65
# University Rating
# Skew : 0.09
# Kurt : -0.81
# SOP
# Skew : -0.23
# Kurt : -0.71
# LOR
# Skew : -0.15
# Kurt : -0.75
# CGPA
# Skew : -0.03
# Kurt : -0.56
# Research
# Skew : -0.24
# Kurt : -1.95
# Admit
# Skew : 0.96
# Kurt : -1.08

# %% [markdown]
# **Observations:**
#
# - The average GRE score of students applying for UCLA is ~316 out of 340. Some students scored full marks on GRE.
# -  The average TOEFL score of students applying for UCLA is ~107 out of 120. Some students scored full marks on TOEFL.
# - There are students with all kinds of ratings for bachelor's University, SOP, and LOR - ratings ranging from 1 to 5.
# -  The average CGPA of students applying for UCLA is 8.57.
# - Majority of students (~56%) have research experience.
# - As per our assumption, on average 28.4% of students would get admission to UCLA.

# %% [markdown]
# ### **Let's visualize the dataset to see some patterns**

# %%
#Printing the % sub categories of each category
for i in ['University Rating','SOP','LOR ','Research','Admit']:
    print(data[i].value_counts(normalize=True))
    print('*'*40)
# Out:
# 3    0.324
# 2    0.252
# 4    0.210
# 5    0.146
# 1    0.068
# Name: University Rating, dtype: float64
# ****************************************
# 4.0    0.178
# 3.5    0.176
# 3.0    0.160
# 2.5    0.128
# 4.5    0.126
# 2.0    0.086
# 5.0    0.084
# 1.5    0.050
# 1.0    0.012
# Name: SOP, dtype: float64
# ****************************************
# 3.0    0.198
# 4.0    0.188
# 3.5    0.172
# 4.5    0.126
# 5.0    0.100
# 2.5    0.100
# 2.0    0.092
# 1.5    0.022
# 1.0    0.002
# Name: LOR , dtype: float64
# ****************************************
# 1    0.56
# 0    0.44
# Name: Research, dtype: float64
# ****************************************
# 0    0.716
# 1    0.284
# Name: Admit, dtype: float64
# ****************************************

# %%
### Bivariate Plots

# %%
#pairplot with attrition as hue to get relationships
sns.pairplot(data
             ,hue="Admit",diag_kind ='kde'
             ,plot_kws = {'alpha': 0.6, 's': 80, 'edgecolor': 'k'},size = 4)
#Can see linear seperation for Class so running Deep Learning is a over kill in this scenario
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/axisgrid.py:2076: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
#plotting the correlation between numerical variables
plt.figure(figsize=(15,8))
sns.heatmap(data.corr(),annot=True, fmt='0.2f', cmap='YlGnBu')
#Using DNN is a overkill in this scenario

# %%
plt.figure(figsize=(15,8))
sns.scatterplot(data=data, 
           x='GRE Score', 
           y='TOEFL Score', 
           hue='Admit',
           size='SOP');

# Visual display 4D here - X, Y, Size and Color
# Easily split the data using a linear model

# %% [markdown]
# **Observations:**
#
# - There is a linear relationship between GRE and TOEFL scores. This implies that students scoring high one of them would score high in the other as well.
# - With the increase in GRE and TOEFL scores, the strength of SOP increases.
# - We can see a distinction between students who were admitted (denoted by orange) vs those who were not admitted (denoted by blue). We can see that majority of students who were admitted have GRE score greater than 320, TOEFL score greater than 105, and SOP of 4 or higher.

# %%
plt.figure(figsize=(10,7))
sns.boxplot(data=data,
             x='University Rating', 
             y='CGPA',
             hue='Admit')
plt.title('Relationship between different University Rating and CGPA')
plt.show()

#Higher University rating, better the grades - Generally inverse relationship

# %% [markdown]
# **Observations:**
#
# - We can see that, with increasing university ratings, the CGPA is also increasing, and also the chances of getting admitted to UCLA increases.
# - The CGPA of students getting admission to UCLA is higher as compared to students not getting admission to UCLA which makes sense.

# %% [markdown]
# ### **Data Preparation**

# %% [markdown]
# This dataset contains both numerical and categorical variables. We need to treat them first before we pass them onto the neural network. We will perform below pre-processing steps -
# *   One hot encoding of categorical variables
# *   Scaling numerical variables
#
# An important point to remember: Before we scale numerical variables, we would first split the dataset into train and test datasets and perform scaling separately. Otherwise, we would be leaking information from the test data to the train data and the resulting model might give a false sense of good performance. This is known as **data leakage** which we would like to avoid.

# %% [markdown]
# In this dataset, although the variable **University Rating** is encoded as a numerical variable. But it is denoting or signifying the quality of the university, so that is why this is a categorical variable and we would be creating one-hot encoding or dummy variables for this variable.

# %%
#Creating one hot encoding for the column - University Rating and then dropping University Rating
one_hot_data = pd.concat([data, pd.get_dummies(data['University Rating'], prefix = 'University Rating')], axis=1)
one_hot_data = one_hot_data.drop(columns = 'University Rating')
one_hot_data.head()
# Out:
#    GRE Score  TOEFL Score  ...  University Rating_4  University Rating_5
# 0        337          118  ...                    1                    0
# 1        324          107  ...                    1                    0
# 2        316          104  ...                    0                    0
# 3        322          110  ...                    0                    0
# 4        314          103  ...                    0                    0
#
# [5 rows x 12 columns]

# %% [markdown]
# Now, let's split the dataset into train and test datasets. To do that, we would be extracting all the **independent variables** and save them into a variable **features**. And the target variable **Admit** would be saved into a variable **target**. These two variables will be used to split the parent dataset into train and test datasets.

# %%
features = one_hot_data.drop(['Admit'], axis=1)
target = one_hot_data['Admit']

# %% [markdown]
# The size of the dataset is small and the Keras implementation provides an argument for selecting some percentage of training data as validation data to check the accuracy of the model. Therefore, we will split the data into an 80:20 ratio.

# %%
#Splitting the dataset into train and test data
X_train, X_test, y_train, y_test =  train_test_split(features, target, test_size=0.2, random_state=42,stratify=target)

# %%
print(X_train.shape)
print(X_test.shape)
# Out:
# (400, 11)
# (100, 11)

# %%
pd.DataFrame(y_train).value_counts(normalize=True)
# Out:
# Admit
# 0        0.715
# 1        0.285
# dtype: float64

# %%
pd.DataFrame(y_test).value_counts(normalize=True)
# Out:
# Admit
# 0        0.72
# 1        0.28
# dtype: float64

# %% [markdown]
# Now, we will perform scaling on the numerical variables separately for train and test sets. We will perform **fit** and **transform** on the train data and then we will only perform **transform** on the test data.

# %%
scaler = x - mean(x) / sd(x)

# %%
scaler = MinMaxScaler()
# here we are passing all the features (numerical and categorical), that's okay as min-max scaler will not change values of categorical variables
X_train_normalized = scaler.fit_transform(X_train)

# %%
#Good practice to tranform test data to avoid Data Leakage problem 
X_test_normalized = scaler.transform(X_test)

# %% [markdown]
# ### **Model Architecture**

# %% [markdown]
# In neural networks, there are so many hyper-parameters that you can play around with and tune the network to get the best results. Some of them are -
#
#
#
# 1.   Number of hidden layers
# 2.   Number of neurons in each hidden layer
# 3.   Activation functions in hidden layers
# 4.   Optimizers
# 5.   Random initialization of weights and biases
# 6.   Batch size
# 7.   Learning rate
# 8.   Early stopping
# 9.   L1 and L2 Regularization
# 10.  Dropout
# 11.  Momentum
#
# and so on...

# %% [markdown]
# First, let's set the seed for random number generators in NumPy, Python, and TensorFlow to be able to reproduce the same results everytime we run the code.

# %%
#Fixing the seed for random number generators
np.random.seed(42)
import random
random.seed(42)
tf.random.set_seed(42)

# %% [markdown]
# Let's build a feed forward neural network with 2 hidden layers and the output layer.

# %%
# we will be adding the layers sequentially
model_1 = Sequential()

# first hidden layer with 128 neurons and relu activation function, the input shape tuple denotes number of independent variables
model_1.add(Dense(128, activation='relu', input_shape=(11,)))

# we will be switching 20% of neurons randomly at each iteration to avoid overfitting
model_1.add(Dropout(0.2))

# second hidden layer with 64 neurons and relu activation function
model_1.add(Dense(64, activation='relu'))

# we will be switching 10% of neurons off randomly at each iteration to avoid overfitting
model_1.add(Dropout(0.1))

# output layer with only one neuron and sigmoid as activation function will give the probability of students getting admitted into UCLA  
model_1.add(Dense(1, activation='sigmoid'))

# %% [markdown]
# Once we are done with the model architecture, we need to compile the model, where we need to provide the loss function that we want to optimize, the optimization algorithm, and the evaluation metric that we are interested in to evaluate the model.

# %% [markdown]
# Since this is a binary classification task, we will be minimizing the **binary_crossentropy** and we can choose one optimizer out of
# 1.   SGD
# 2.   RMSprop
# 3.   Adam
# 4.   Adadelta
# 5.   Adagrad
# 6.   Adamax
# 7.   Nadam
# 8.   Ftrl
#
# This is a hyper-parameter. You can play around with these optimizers to check which one performs better with a particular data.
#
# For now, let's try **adamax** optimizer with **accuracy** as the metric and see the model's summary.

# %% [markdown]
# Keras Documentation
# https://keras.io/
# <br>
# Keras Loss
# https://keras.io/api/losses/
# <br>
# Keras Metrics
# https://keras.io/api/metrics/
# <br>
# Keras Optimizer
# https://keras.io/api/optimizers/

# %%
model_1.compile(loss = 'binary_crossentropy', optimizer='adamax', metrics=['accuracy'])
model_1.summary()

# Input is 11
# Qn How get 1536 params, 8256 params and 65 params
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_3 (Dense)             (None, 128)               1536
#
#  dropout_2 (Dropout)         (None, 128)               0
#
#  dense_4 (Dense)             (None, 64)                8256
#
#  dropout_3 (Dropout)         (None, 64)                0
#
#  dense_5 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 9,857
# Trainable params: 9,857
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Qn How get 1536 params = 128 * 11 + 128
# 8256 = 64*128 + 64 
#  65 = 64*1 + 1

# %% [markdown]
# From the above summary, we can see that this architecture will train a total of **9,857** parameters i.e. weights and biases in the network.

# %% [markdown]
# ### **Training the model**

# %% [markdown]
# Let's now train the model using the below piece of code. We will keep the 10% of the training data for validation.

# %%
X_train_normalized.shape
# Out:
# (400, 11)

# %%
history_1 = model_1.fit(X_train_normalized, 
                    y_train,
                    validation_split=0.1, 
                    epochs=150, 
                    verbose=2,
                    batch_size=200)
# Perform validation split while training so not required to split data before
# Out:
# Epoch 1/150
# 2/2 - 0s - loss: 0.1350 - accuracy: 0.9417 - val_loss: 0.0416 - val_accuracy: 1.0000 - 64ms/epoch - 32ms/step
# Epoch 2/150
# 2/2 - 0s - loss: 0.1227 - accuracy: 0.9528 - val_loss: 0.0415 - val_accuracy: 1.0000 - 30ms/epoch - 15ms/step
# Epoch 3/150
# 2/2 - 0s - loss: 0.1456 - accuracy: 0.9250 - val_loss: 0.0414 - val_accuracy: 1.0000 - 48ms/epoch - 24ms/step
# Epoch 4/150
# 2/2 - 0s - loss: 0.1360 - accuracy: 0.9389 - val_loss: 0.0415 - val_accuracy: 1.0000 - 31ms/epoch - 16ms/step
# Epoch 5/150
# 2/2 - 0s - loss: 0.1298 - accuracy: 0.9333 - val_loss: 0.0416 - val_accuracy: 1.0000 - 30ms/epoch - 15ms/step
# Epoch 6/150
# 2/2 - 0s - loss: 0.1366 - accuracy: 0.9389 - val_loss: 0.0416 - val_accuracy: 1.0000 - 44ms/epoch - 22ms/step
# Epoch 7/150
# 2/2 - 0s - loss: 0.1257 - accuracy: 0.9444 - val_loss: 0.0416 - val_accuracy: 1.0000 - 33ms/epoch - 17ms/step
# Epoch 8/150
# 2/2 - 0s - loss: 0.1532 - accuracy: 0.9333 - val_loss: 0.0415 - val_accuracy: 1.0000 - 31ms/epoch - 15ms/step
# Epoch 9/150
# 2/2 - 0s - loss: 0.1265 - accuracy: 0.9444 - val_loss: 0.0414 - val_accuracy: 1.0000 - 31ms/epoch - 15ms/step
# Epoch 10/150
# 2/2 - 0s - loss: 0.1552 - accuracy: 0.9278 - val_loss: 0.0413 - val_accuracy: 1.0000 - 34ms/epoch - 17ms/step
# Epoch 11/150
# 2/2 - 0s - loss: 0.1289 - accuracy: 0.9528 - val_loss: 0.0411 - val_accuracy: 1.0000 - 34ms/epoch - 17ms/step
# Epoch 12/150
# 2/2 - 0s - loss: 0.1366 - accuracy: 0.9333 - val_loss: 0.0409 - val_accuracy: 1.0000 - 32ms/epoch - 16ms/step
# Epoch 13/150
# 2/2 - 0s - loss: 0.1367 - accuracy: 0.9444 - val_loss: 0.0408 - val_accuracy: 1.0000 - 46ms/epoch - 23ms/step
# Epoch 14/150
# 2/2 - 0s - loss: 0.1354 - accuracy: 0.9361 - val_loss: 0.0408 - val_accuracy: 1.0000 - 33ms/epoch - 16ms/step
# Epoch 15/150
# 2/2 - 0s - loss: 0.1409 - accuracy: 0.9306 - val_loss: 0.0409 - val_accuracy: 1.0000 - 37ms/epoch - 19ms/step
# Epoch 16/150
# 2/2 - 0s - loss: 0.1384 - accuracy: 0.9306 - val_loss: 0.0411 - val_accuracy: 1.0000 - 35ms/epoch - 17ms/step
# Epoch 17/150
# 2/2 - 0s - loss: 0.1389 - accuracy: 0.9333 - val_loss: 0.0413 - val_accuracy: 1.0000 - 34ms/epoch - 17ms/step
# Epoch 18/150
# 2/2 - 0s - loss: 0.1452 - accuracy: 0.9389 - val_loss: 0.0416 - val_accuracy: 1.0000 - 35ms/epoch - 18ms/step
# Epoch 19/150
# 2/2 - 0s - loss: 0.1284 - accuracy: 0.9333 - val_loss: 0.0419 - val_accuracy: 1.0000 - 36ms/epoch - 18ms/step
# Epoch 20/150
# 2/2 - 0s - loss: 0.1422 - accuracy: 0.9417 - val_loss: 0.0420 - val_accuracy: 1.0000 - 45ms/epoch - 22ms/step
# Epoch 21/150
# 2/2 - 0s - loss: 0.1298 - accuracy: 0.9361 - val_loss: 0.0421 - val_accuracy: 1.0000 - 32ms/epoch - 16ms/step
# Epoch 22/150
# 2/2 - 0s - loss: 0.1254 - accuracy: 0.9472 - val_loss: 0.0421 - val_accuracy: 1.0000 - 34ms/epoch - 17ms/step
# Epoch 23/150
# 2/2 - 0s - loss: 0.1318 - accuracy: 0.9417 - val_loss: 0.0420 - val_accuracy: 1.0000 - 37ms/epoch - 19ms/step
# Epoch 24/150
# 2/2 - 0s - loss: 0.1325 - accuracy: 0.9361 - val_loss: 0.0419 - val_accuracy: 1.0000 - 33ms/epoch - 16ms/step
# Epoch 25/150
# 2/2 - 0s - loss: 0.1369 - accuracy: 0.9361 - val_loss: 0.0418 - val_accuracy: 1.0000 - 28ms/epoch - 14ms/step
# Epoch 26/150
# 2/2 - 0s - loss: 0.1290 - accuracy: 0.9528 - val_loss: 0.0416 - val_accuracy: 1.0000 - 37ms/epoch - 18ms/step
# Epoch 27/150
# 2/2 - 0s - loss: 0.1514 - accuracy: 0.9278 - val_loss: 0.0414 - val_accuracy: 1.0000 - 36ms/epoch - 18ms/step
# Epoch 28/150
# 2/2 - 0s - loss: 0.1277 - accuracy: 0.9472 - val_loss: 0.0412 - val_accuracy: 1.0000 - 41ms/epoch - 20ms/step
# Epoch 29/150
# 2/2 - 0s - loss: 0.1428 - accuracy: 0.9333 - val_loss: 0.0410 - val_accuracy: 1.0000 - 34ms/epoch - 17ms/step
# Epoch 30/150
# 2/2 - 0s - loss: 0.1435 - accuracy: 0.9361 - val_loss: 0.0409 - val_accuracy: 1.0000 - 28ms/epoch - 14ms/step
# Epoch 31/150
# 2/2 - 0s - loss: 0.1414 - accuracy: 0.9417 - val_loss: 0.0408 - val_accuracy: 1.0000 - 29ms/epoch - 14ms/step
# Epoch 32/150
# 2/2 - 0s - loss: 0.1487 - accuracy: 0.9278 - val_loss: 0.0408 - val_accuracy: 1.0000 - 30ms/epoch - 15ms/step
# Epoch 33/150
# 2/2 - 0s - loss: 0.1300 - accuracy: 0.9389 - val_loss: 0.0407 - val_accuracy: 1.0000 - 36ms/epoch - 18ms/step
# Epoch 34/150
# 2/2 - 0s - loss: 0.1361 - accuracy: 0.9361 - val_loss: 0.0408 - val_accuracy: 1.0000 - 33ms/epoch - 16ms/step
# Epoch 35/150
# 2/2 - 0s - loss: 0.1259 - accuracy: 0.9389 - val_loss: 0.0409 - val_accuracy: 1.0000 - 33ms/epoch - 16ms/step
# Epoch 36/150
# 2/2 - 0s - loss: 0.1367 - accuracy: 0.9333 - val_loss: 0.0410 - val_accuracy: 1.0000 - 39ms/epoch - 20ms/step
# Epoch 37/150
# 2/2 - 0s - loss: 0.1324 - accuracy: 0.9361 - val_loss: 0.0411 - val_accuracy: 1.0000 - 50ms/epoch - 25ms/step
# Epoch 38/150
# 2/2 - 0s - loss: 0.1285 - accuracy: 0.9389 - val_loss: 0.0410 - val_accuracy: 1.0000 - 36ms/epoch - 18ms/step
# Epoch 39/150
# 2/2 - 0s - loss: 0.1437 - accuracy: 0.9306 - val_loss: 0.0410 - val_accuracy: 1.0000 - 35ms/epoch - 18ms/step
# Epoch 40/150
# 2/2 - 0s - loss: 0.1209 - accuracy: 0.9472 - val_loss: 0.0409 - val_accuracy: 1.0000 - 42ms/epoch - 21ms/step
# Epoch 41/150
# 2/2 - 0s - loss: 0.1280 - accuracy: 0.9472 - val_loss: 0.0409 - val_accuracy: 1.0000 - 36ms/epoch - 18ms/step
# Epoch 42/150
# 2/2 - 0s - loss: 0.1322 - accuracy: 0.9444 - val_loss: 0.0407 - val_accuracy: 1.0000 - 39ms/epoch - 19ms/step
# Epoch 43/150
# 2/2 - 0s - loss: 0.1238 - accuracy: 0.9500 - val_loss: 0.0406 - val_accuracy: 1.0000 - 41ms/epoch - 21ms/step
# Epoch 44/150
# 2/2 - 0s - loss: 0.1352 - accuracy: 0.9306 - val_loss: 0.0405 - val_accuracy: 1.0000 - 43ms/epoch - 21ms/step
# Epoch 45/150
# 2/2 - 0s - loss: 0.1371 - accuracy: 0.9389 - val_loss: 0.0404 - val_accuracy: 1.0000 - 38ms/epoch - 19ms/step
# Epoch 46/150
# 2/2 - 0s - loss: 0.1428 - accuracy: 0.9472 - val_loss: 0.0404 - val_accuracy: 1.0000 - 32ms/epoch - 16ms/step
# Epoch 47/150
# 2/2 - 0s - loss: 0.1355 - accuracy: 0.9389 - val_loss: 0.0405 - val_accuracy: 1.0000 - 34ms/epoch - 17ms/step
# Epoch 48/150
# 2/2 - 0s - loss: 0.1256 - accuracy: 0.9389 - val_loss: 0.0405 - val_accuracy: 1.0000 - 35ms/epoch - 18ms/step
# Epoch 49/150
# 2/2 - 0s - loss: 0.1348 - accuracy: 0.9472 - val_loss: 0.0405 - val_accuracy: 1.0000 - 35ms/epoch - 18ms/step
# Epoch 50/150
# 2/2 - 0s - loss: 0.1360 - accuracy: 0.9472 - val_loss: 0.0405 - val_accuracy: 1.0000 - 27ms/epoch - 14ms/step
# Epoch 51/150
# 2/2 - 0s - loss: 0.1380 - accuracy: 0.9444 - val_loss: 0.0404 - val_accuracy: 1.0000 - 31ms/epoch - 15ms/step
# Epoch 52/150
# 2/2 - 0s - loss: 0.1391 - accuracy: 0.9306 - val_loss: 0.0405 - val_accuracy: 1.0000 - 31ms/epoch - 15ms/step
# Epoch 53/150
# 2/2 - 0s - loss: 0.1409 - accuracy: 0.9444 - val_loss: 0.0407 - val_accuracy: 1.0000 - 32ms/epoch - 16ms/step
# Epoch 54/150
# 2/2 - 0s - loss: 0.1530 - accuracy: 0.9306 - val_loss: 0.0408 - val_accuracy: 1.0000 - 30ms/epoch - 15ms/step
# Epoch 55/150
# 2/2 - 0s - loss: 0.1245 - accuracy: 0.9472 - val_loss: 0.0409 - val_accuracy: 1.0000 - 32ms/epoch - 16ms/step
# Epoch 56/150
# 2/2 - 0s - loss: 0.1480 - accuracy: 0.9361 - val_loss: 0.0410 - val_accuracy: 1.0000 - 29ms/epoch - 15ms/step
# Epoch 57/150
# 2/2 - 0s - loss: 0.1263 - accuracy: 0.9444 - val_loss: 0.0411 - val_accuracy: 1.0000 - 32ms/epoch - 16ms/step
# Epoch 58/150
# 2/2 - 0s - loss: 0.1303 - accuracy: 0.9389 - val_loss: 0.0412 - val_accuracy: 1.0000 - 31ms/epoch - 15ms/step
# Epoch 59/150
# 2/2 - 0s - loss: 0.1471 - accuracy: 0.9361 - val_loss: 0.0414 - val_accuracy: 1.0000 - 32ms/epoch - 16ms/step
# Epoch 60/150
# 2/2 - 0s - loss: 0.1326 - accuracy: 0.9333 - val_loss: 0.0417 - val_accuracy: 1.0000 - 31ms/epoch - 15ms/step
# Epoch 61/150
# 2/2 - 0s - loss: 0.1418 - accuracy: 0.9389 - val_loss: 0.0417 - val_accuracy: 1.0000 - 32ms/epoch - 16ms/step
# Epoch 62/150
# 2/2 - 0s - loss: 0.1171 - accuracy: 0.9444 - val_loss: 0.0416 - val_accuracy: 1.0000 - 37ms/epoch - 18ms/step
# Epoch 63/150
# 2/2 - 0s - loss: 0.1336 - accuracy: 0.9306 - val_loss: 0.0415 - val_accuracy: 1.0000 - 40ms/epoch - 20ms/step
# Epoch 64/150
# 2/2 - 0s - loss: 0.1379 - accuracy: 0.9333 - val_loss: 0.0413 - val_accuracy: 1.0000 - 35ms/epoch - 17ms/step
# Epoch 65/150
# 2/2 - 0s - loss: 0.1437 - accuracy: 0.9333 - val_loss: 0.0409 - val_accuracy: 1.0000 - 38ms/epoch - 19ms/step
# Epoch 66/150
# 2/2 - 0s - loss: 0.1207 - accuracy: 0.9417 - val_loss: 0.0406 - val_accuracy: 1.0000 - 35ms/epoch - 18ms/step
# Epoch 67/150
# 2/2 - 0s - loss: 0.1480 - accuracy: 0.9222 - val_loss: 0.0405 - val_accuracy: 1.0000 - 34ms/epoch - 17ms/step
# Epoch 68/150
# 2/2 - 0s - loss: 0.1354 - accuracy: 0.9583 - val_loss: 0.0404 - val_accuracy: 1.0000 - 36ms/epoch - 18ms/step
# Epoch 69/150
# 2/2 - 0s - loss: 0.1246 - accuracy: 0.9472 - val_loss: 0.0403 - val_accuracy: 1.0000 - 33ms/epoch - 16ms/step
# Epoch 70/150
# 2/2 - 0s - loss: 0.1351 - accuracy: 0.9417 - val_loss: 0.0404 - val_accuracy: 1.0000 - 44ms/epoch - 22ms/step
# Epoch 71/150
# 2/2 - 0s - loss: 0.1351 - accuracy: 0.9472 - val_loss: 0.0405 - val_accuracy: 1.0000 - 61ms/epoch - 31ms/step
# Epoch 72/150
# 2/2 - 0s - loss: 0.1451 - accuracy: 0.9361 - val_loss: 0.0406 - val_accuracy: 1.0000 - 32ms/epoch - 16ms/step
# Epoch 73/150
# 2/2 - 0s - loss: 0.1343 - accuracy: 0.9361 - val_loss: 0.0404 - val_accuracy: 1.0000 - 33ms/epoch - 17ms/step
# Epoch 74/150
# 2/2 - 0s - loss: 0.1320 - accuracy: 0.9306 - val_loss: 0.0403 - val_accuracy: 1.0000 - 32ms/epoch - 16ms/step
# Epoch 75/150
# 2/2 - 0s - loss: 0.1549 - accuracy: 0.9306 - val_loss: 0.0402 - val_accuracy: 1.0000 - 33ms/epoch - 16ms/step
# Epoch 76/150
# 2/2 - 0s - loss: 0.1350 - accuracy: 0.9472 - val_loss: 0.0402 - val_accuracy: 1.0000 - 33ms/epoch - 16ms/step
# Epoch 77/150
# 2/2 - 0s - loss: 0.1356 - accuracy: 0.9444 - val_loss: 0.0402 - val_accuracy: 1.0000 - 36ms/epoch - 18ms/step
# Epoch 78/150
# 2/2 - 0s - loss: 0.1366 - accuracy: 0.9417 - val_loss: 0.0403 - val_accuracy: 1.0000 - 37ms/epoch - 18ms/step
# Epoch 79/150
# 2/2 - 0s - loss: 0.1287 - accuracy: 0.9333 - val_loss: 0.0404 - val_accuracy: 1.0000 - 40ms/epoch - 20ms/step
# Epoch 80/150
# 2/2 - 0s - loss: 0.1327 - accuracy: 0.9333 - val_loss: 0.0404 - val_accuracy: 1.0000 - 35ms/epoch - 17ms/step
# Epoch 81/150
# 2/2 - 0s - loss: 0.1311 - accuracy: 0.9444 - val_loss: 0.0405 - val_accuracy: 1.0000 - 36ms/epoch - 18ms/step
# Epoch 82/150
# 2/2 - 0s - loss: 0.1328 - accuracy: 0.9417 - val_loss: 0.0405 - val_accuracy: 1.0000 - 32ms/epoch - 16ms/step
# Epoch 83/150
# 2/2 - 0s - loss: 0.1287 - accuracy: 0.9472 - val_loss: 0.0403 - val_accuracy: 1.0000 - 29ms/epoch - 15ms/step
# Epoch 84/150
# 2/2 - 0s - loss: 0.1308 - accuracy: 0.9417 - val_loss: 0.0401 - val_accuracy: 1.0000 - 41ms/epoch - 21ms/step
# Epoch 85/150
# 2/2 - 0s - loss: 0.1435 - accuracy: 0.9361 - val_loss: 0.0400 - val_accuracy: 1.0000 - 36ms/epoch - 18ms/step
# Epoch 86/150
# 2/2 - 0s - loss: 0.1325 - accuracy: 0.9361 - val_loss: 0.0397 - val_accuracy: 1.0000 - 29ms/epoch - 15ms/step
# Epoch 87/150
# 2/2 - 0s - loss: 0.1416 - accuracy: 0.9389 - val_loss: 0.0395 - val_accuracy: 1.0000 - 37ms/epoch - 18ms/step
# Epoch 88/150
# 2/2 - 0s - loss: 0.1263 - accuracy: 0.9444 - val_loss: 0.0395 - val_accuracy: 1.0000 - 30ms/epoch - 15ms/step
# Epoch 89/150
# 2/2 - 0s - loss: 0.1233 - accuracy: 0.9361 - val_loss: 0.0396 - val_accuracy: 1.0000 - 35ms/epoch - 17ms/step
# Epoch 90/150
# 2/2 - 0s - loss: 0.1261 - accuracy: 0.9583 - val_loss: 0.0396 - val_accuracy: 1.0000 - 34ms/epoch - 17ms/step
# Epoch 91/150
# 2/2 - 0s - loss: 0.1363 - accuracy: 0.9250 - val_loss: 0.0398 - val_accuracy: 1.0000 - 34ms/epoch - 17ms/step
# Epoch 92/150
# 2/2 - 0s - loss: 0.1371 - accuracy: 0.9333 - val_loss: 0.0398 - val_accuracy: 1.0000 - 42ms/epoch - 21ms/step
# Epoch 93/150
# 2/2 - 0s - loss: 0.1360 - accuracy: 0.9361 - val_loss: 0.0399 - val_accuracy: 1.0000 - 35ms/epoch - 18ms/step
# Epoch 94/150
# 2/2 - 0s - loss: 0.1438 - accuracy: 0.9333 - val_loss: 0.0400 - val_accuracy: 1.0000 - 42ms/epoch - 21ms/step
# Epoch 95/150
# 2/2 - 0s - loss: 0.1363 - accuracy: 0.9361 - val_loss: 0.0400 - val_accuracy: 1.0000 - 39ms/epoch - 20ms/step
# Epoch 96/150
# 2/2 - 0s - loss: 0.1467 - accuracy: 0.9333 - val_loss: 0.0400 - val_accuracy: 1.0000 - 34ms/epoch - 17ms/step
# Epoch 97/150
# 2/2 - 0s - loss: 0.1310 - accuracy: 0.9417 - val_loss: 0.0401 - val_accuracy: 1.0000 - 38ms/epoch - 19ms/step
# Epoch 98/150
# 2/2 - 0s - loss: 0.1268 - accuracy: 0.9528 - val_loss: 0.0399 - val_accuracy: 1.0000 - 37ms/epoch - 18ms/step
# Epoch 99/150
# 2/2 - 0s - loss: 0.1275 - accuracy: 0.9500 - val_loss: 0.0396 - val_accuracy: 1.0000 - 39ms/epoch - 19ms/step
# Epoch 100/150
# 2/2 - 0s - loss: 0.1499 - accuracy: 0.9306 - val_loss: 0.0396 - val_accuracy: 1.0000 - 33ms/epoch - 16ms/step
# Epoch 101/150
# 2/2 - 0s - loss: 0.1300 - accuracy: 0.9389 - val_loss: 0.0396 - val_accuracy: 1.0000 - 52ms/epoch - 26ms/step
# Epoch 102/150
# 2/2 - 0s - loss: 0.1285 - accuracy: 0.9306 - val_loss: 0.0397 - val_accuracy: 1.0000 - 47ms/epoch - 24ms/step
# Epoch 103/150
# 2/2 - 0s - loss: 0.1322 - accuracy: 0.9389 - val_loss: 0.0397 - val_accuracy: 1.0000 - 39ms/epoch - 19ms/step
# Epoch 104/150
# 2/2 - 0s - loss: 0.1496 - accuracy: 0.9417 - val_loss: 0.0399 - val_accuracy: 1.0000 - 34ms/epoch - 17ms/step
# Epoch 105/150
# 2/2 - 0s - loss: 0.1300 - accuracy: 0.9444 - val_loss: 0.0399 - val_accuracy: 1.0000 - 32ms/epoch - 16ms/step
# Epoch 106/150
# 2/2 - 0s - loss: 0.1358 - accuracy: 0.9417 - val_loss: 0.0397 - val_accuracy: 1.0000 - 35ms/epoch - 18ms/step
# Epoch 107/150
# 2/2 - 0s - loss: 0.1241 - accuracy: 0.9389 - val_loss: 0.0396 - val_accuracy: 1.0000 - 30ms/epoch - 15ms/step
# Epoch 108/150
# 2/2 - 0s - loss: 0.1342 - accuracy: 0.9444 - val_loss: 0.0396 - val_accuracy: 1.0000 - 32ms/epoch - 16ms/step
# Epoch 109/150
# 2/2 - 0s - loss: 0.1484 - accuracy: 0.9333 - val_loss: 0.0396 - val_accuracy: 1.0000 - 38ms/epoch - 19ms/step
# Epoch 110/150
# 2/2 - 0s - loss: 0.1231 - accuracy: 0.9444 - val_loss: 0.0397 - val_accuracy: 1.0000 - 34ms/epoch - 17ms/step
# Epoch 111/150
# 2/2 - 0s - loss: 0.1403 - accuracy: 0.9444 - val_loss: 0.0398 - val_accuracy: 1.0000 - 41ms/epoch - 20ms/step
# Epoch 112/150
# 2/2 - 0s - loss: 0.1344 - accuracy: 0.9361 - val_loss: 0.0399 - val_accuracy: 1.0000 - 34ms/epoch - 17ms/step
# Epoch 113/150
# 2/2 - 0s - loss: 0.1400 - accuracy: 0.9389 - val_loss: 0.0399 - val_accuracy: 1.0000 - 36ms/epoch - 18ms/step
# Epoch 114/150
# 2/2 - 0s - loss: 0.1275 - accuracy: 0.9500 - val_loss: 0.0399 - val_accuracy: 1.0000 - 36ms/epoch - 18ms/step
# Epoch 115/150
# 2/2 - 0s - loss: 0.1323 - accuracy: 0.9333 - val_loss: 0.0400 - val_accuracy: 1.0000 - 37ms/epoch - 19ms/step
# Epoch 116/150
# 2/2 - 0s - loss: 0.1298 - accuracy: 0.9389 - val_loss: 0.0399 - val_accuracy: 1.0000 - 34ms/epoch - 17ms/step
# Epoch 117/150
# 2/2 - 0s - loss: 0.1244 - accuracy: 0.9361 - val_loss: 0.0398 - val_accuracy: 1.0000 - 34ms/epoch - 17ms/step
# Epoch 118/150
# 2/2 - 0s - loss: 0.1192 - accuracy: 0.9417 - val_loss: 0.0398 - val_accuracy: 1.0000 - 42ms/epoch - 21ms/step
# Epoch 119/150
# 2/2 - 0s - loss: 0.1262 - accuracy: 0.9417 - val_loss: 0.0398 - val_accuracy: 1.0000 - 42ms/epoch - 21ms/step
# Epoch 120/150
# 2/2 - 0s - loss: 0.1372 - accuracy: 0.9417 - val_loss: 0.0397 - val_accuracy: 1.0000 - 36ms/epoch - 18ms/step
# Epoch 121/150
# 2/2 - 0s - loss: 0.1508 - accuracy: 0.9278 - val_loss: 0.0398 - val_accuracy: 1.0000 - 33ms/epoch - 16ms/step
# Epoch 122/150
# 2/2 - 0s - loss: 0.1247 - accuracy: 0.9472 - val_loss: 0.0399 - val_accuracy: 1.0000 - 34ms/epoch - 17ms/step
# Epoch 123/150
# 2/2 - 0s - loss: 0.1326 - accuracy: 0.9389 - val_loss: 0.0399 - val_accuracy: 1.0000 - 35ms/epoch - 17ms/step
# Epoch 124/150
# 2/2 - 0s - loss: 0.1247 - accuracy: 0.9417 - val_loss: 0.0398 - val_accuracy: 1.0000 - 33ms/epoch - 16ms/step
# Epoch 125/150
# 2/2 - 0s - loss: 0.1156 - accuracy: 0.9417 - val_loss: 0.0399 - val_accuracy: 1.0000 - 39ms/epoch - 20ms/step
# Epoch 126/150
# 2/2 - 0s - loss: 0.1215 - accuracy: 0.9444 - val_loss: 0.0399 - val_accuracy: 1.0000 - 32ms/epoch - 16ms/step
# Epoch 127/150
# 2/2 - 0s - loss: 0.1430 - accuracy: 0.9333 - val_loss: 0.0398 - val_accuracy: 1.0000 - 28ms/epoch - 14ms/step
# Epoch 128/150
# 2/2 - 0s - loss: 0.1387 - accuracy: 0.9389 - val_loss: 0.0399 - val_accuracy: 1.0000 - 34ms/epoch - 17ms/step
# Epoch 129/150
# 2/2 - 0s - loss: 0.1381 - accuracy: 0.9278 - val_loss: 0.0400 - val_accuracy: 1.0000 - 35ms/epoch - 18ms/step
# Epoch 130/150
# 2/2 - 0s - loss: 0.1409 - accuracy: 0.9361 - val_loss: 0.0401 - val_accuracy: 1.0000 - 32ms/epoch - 16ms/step
# Epoch 131/150
# 2/2 - 0s - loss: 0.1306 - accuracy: 0.9417 - val_loss: 0.0400 - val_accuracy: 1.0000 - 32ms/epoch - 16ms/step
# Epoch 132/150
# 2/2 - 0s - loss: 0.1207 - accuracy: 0.9500 - val_loss: 0.0399 - val_accuracy: 1.0000 - 33ms/epoch - 17ms/step
# Epoch 133/150
# 2/2 - 0s - loss: 0.1312 - accuracy: 0.9472 - val_loss: 0.0399 - val_accuracy: 1.0000 - 42ms/epoch - 21ms/step
# Epoch 134/150
# 2/2 - 0s - loss: 0.1265 - accuracy: 0.9444 - val_loss: 0.0400 - val_accuracy: 1.0000 - 36ms/epoch - 18ms/step
# Epoch 135/150
# 2/2 - 0s - loss: 0.1307 - accuracy: 0.9333 - val_loss: 0.0401 - val_accuracy: 1.0000 - 37ms/epoch - 18ms/step
# Epoch 136/150
# 2/2 - 0s - loss: 0.1377 - accuracy: 0.9361 - val_loss: 0.0402 - val_accuracy: 1.0000 - 36ms/epoch - 18ms/step
# Epoch 137/150
# 2/2 - 0s - loss: 0.1321 - accuracy: 0.9278 - val_loss: 0.0402 - val_accuracy: 1.0000 - 34ms/epoch - 17ms/step
# Epoch 138/150
# 2/2 - 0s - loss: 0.1408 - accuracy: 0.9361 - val_loss: 0.0401 - val_accuracy: 1.0000 - 35ms/epoch - 18ms/step
# Epoch 139/150
# 2/2 - 0s - loss: 0.1362 - accuracy: 0.9278 - val_loss: 0.0400 - val_accuracy: 1.0000 - 36ms/epoch - 18ms/step
# Epoch 140/150
# 2/2 - 0s - loss: 0.1351 - accuracy: 0.9389 - val_loss: 0.0398 - val_accuracy: 1.0000 - 42ms/epoch - 21ms/step
# Epoch 141/150
# 2/2 - 0s - loss: 0.1236 - accuracy: 0.9444 - val_loss: 0.0395 - val_accuracy: 1.0000 - 39ms/epoch - 20ms/step
# Epoch 142/150
# 2/2 - 0s - loss: 0.1321 - accuracy: 0.9389 - val_loss: 0.0396 - val_accuracy: 1.0000 - 43ms/epoch - 21ms/step
# Epoch 143/150
# 2/2 - 0s - loss: 0.1236 - accuracy: 0.9389 - val_loss: 0.0396 - val_accuracy: 1.0000 - 34ms/epoch - 17ms/step
# Epoch 144/150
# 2/2 - 0s - loss: 0.1312 - accuracy: 0.9389 - val_loss: 0.0396 - val_accuracy: 1.0000 - 36ms/epoch - 18ms/step
# Epoch 145/150
# 2/2 - 0s - loss: 0.1206 - accuracy: 0.9500 - val_loss: 0.0397 - val_accuracy: 1.0000 - 34ms/epoch - 17ms/step
# Epoch 146/150
# 2/2 - 0s - loss: 0.1422 - accuracy: 0.9278 - val_loss: 0.0398 - val_accuracy: 1.0000 - 34ms/epoch - 17ms/step
# Epoch 147/150
# 2/2 - 0s - loss: 0.1352 - accuracy: 0.9389 - val_loss: 0.0398 - val_accuracy: 1.0000 - 33ms/epoch - 16ms/step
# Epoch 148/150
# 2/2 - 0s - loss: 0.1184 - accuracy: 0.9500 - val_loss: 0.0398 - val_accuracy: 1.0000 - 33ms/epoch - 17ms/step
# Epoch 149/150
# 2/2 - 0s - loss: 0.1280 - accuracy: 0.9361 - val_loss: 0.0398 - val_accuracy: 1.0000 - 33ms/epoch - 16ms/step
# Epoch 150/150
# 2/2 - 0s - loss: 0.1312 - accuracy: 0.9306 - val_loss: 0.0398 - val_accuracy: 1.0000 - 35ms/epoch - 17ms/step

# %% [markdown]
# ### **Plotting Accuracy vs Epoch Curve**

# %%
plt.plot(history_1.history['accuracy'])
plt.plot(history_1.history['val_accuracy'])
plt.title('Accuracy vs Epochs')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='lower right')
plt.show()
#Fitting a way too complex function for a simple task here - Overfitting

# %% [markdown]
# **Observations:**
#
# - The training accuracy is fluctuating but overall it is increasing with the increase in epochs.
# - The validation accuracy is constant between ~20 to 100 epochs and it is fluctuating a bit post 100 epochs.
# - The model is giving good accuracy. After 150 epochs, the accuracy of the model on the training data is about 93.3% and the validation accuracy is 92.5%.
# - The validation accuracy is closer to the training accuracy. This indicates that the model is giving a generalized performance.

# %% [markdown]
# Let's try to increase the model complexity by tuning some of the hyper-parameters mentioned earlier and check if we can improve the model performance. Out of all the options we have, let's try to change the number of hidden layers, the number of neurons in each hidden layer, the activation function in the hidden layer, the optimizer from **adamax** to **adam**. Also, we have observed that validation accuracy became constant after some epochs, let's try less number of epochs which would also reduce the computation time.

# %% [markdown]
# First, we need to clear the previous model's history from the session. In Keras, we need special command to clear the model's history otherwise the previous model history remains in the backend.
# Also, let's fix the seed again after clearing the backend.

# %%
#Clearing backend
from tensorflow.keras import backend
backend.clear_session()

# %%
#Fixing the seed for random number generators
np.random.seed(42)
import random
random.seed(42)
tf.random.set_seed(42)

# %%
model_2 = Sequential()

model_2.add(Dense(128, activation='tanh', input_shape=(11,)))
model_2.add(Dropout(0.1))
model_2.add(Dense(64, activation='tanh'))
model_2.add(Dropout(0.1))
model_2.add(Dense(32, activation='tanh'))
model_2.add(Dense(1, activation='sigmoid'))

# %%
model_2.compile(loss = 'binary_crossentropy', optimizer='adam', metrics=['accuracy'])
model_2.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 128)               1536
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_1 (Dense)             (None, 64)                8256
#
#  dropout_1 (Dropout)         (None, 64)                0
#
#  dense_2 (Dense)             (None, 32)                2080
#
#  dense_3 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 11,905
# Trainable params: 11,905
# Non-trainable params: 0
# _________________________________________________________________

# %%
history_2 = model_2.fit(X_train_normalized, 
                    y_train, 
                    validation_split=0.1, 
                    epochs=100, 
                    verbose=2,
                    batch_size=200)
# Out:
# Epoch 1/100
# 2/2 - 1s - loss: 0.6499 - accuracy: 0.6556 - val_loss: 0.5988 - val_accuracy: 0.7250 - 867ms/epoch - 433ms/step
# Epoch 2/100
# 2/2 - 0s - loss: 0.5964 - accuracy: 0.7167 - val_loss: 0.5441 - val_accuracy: 0.7250 - 38ms/epoch - 19ms/step
# Epoch 3/100
# 2/2 - 0s - loss: 0.5510 - accuracy: 0.7333 - val_loss: 0.4914 - val_accuracy: 0.7250 - 31ms/epoch - 15ms/step
# Epoch 4/100
# 2/2 - 0s - loss: 0.5076 - accuracy: 0.7750 - val_loss: 0.4416 - val_accuracy: 0.8000 - 32ms/epoch - 16ms/step
# Epoch 5/100
# 2/2 - 0s - loss: 0.4768 - accuracy: 0.8111 - val_loss: 0.3980 - val_accuracy: 0.8750 - 31ms/epoch - 15ms/step
# Epoch 6/100
# 2/2 - 0s - loss: 0.4421 - accuracy: 0.8583 - val_loss: 0.3607 - val_accuracy: 0.9000 - 61ms/epoch - 30ms/step
# Epoch 7/100
# 2/2 - 0s - loss: 0.4144 - accuracy: 0.8500 - val_loss: 0.3287 - val_accuracy: 0.9000 - 38ms/epoch - 19ms/step
# Epoch 8/100
# 2/2 - 0s - loss: 0.3922 - accuracy: 0.8556 - val_loss: 0.3024 - val_accuracy: 0.9000 - 35ms/epoch - 18ms/step
# Epoch 9/100
# 2/2 - 0s - loss: 0.3705 - accuracy: 0.8611 - val_loss: 0.2806 - val_accuracy: 0.9000 - 32ms/epoch - 16ms/step
# Epoch 10/100
# 2/2 - 0s - loss: 0.3627 - accuracy: 0.8583 - val_loss: 0.2619 - val_accuracy: 0.9000 - 35ms/epoch - 18ms/step
# Epoch 11/100
# 2/2 - 0s - loss: 0.3483 - accuracy: 0.8639 - val_loss: 0.2471 - val_accuracy: 0.9000 - 30ms/epoch - 15ms/step
# Epoch 12/100
# 2/2 - 0s - loss: 0.3345 - accuracy: 0.8639 - val_loss: 0.2360 - val_accuracy: 0.9000 - 36ms/epoch - 18ms/step
# Epoch 13/100
# 2/2 - 0s - loss: 0.3316 - accuracy: 0.8639 - val_loss: 0.2274 - val_accuracy: 0.9000 - 35ms/epoch - 17ms/step
# Epoch 14/100
# 2/2 - 0s - loss: 0.3296 - accuracy: 0.8667 - val_loss: 0.2209 - val_accuracy: 0.9000 - 39ms/epoch - 19ms/step
# Epoch 15/100
# 2/2 - 0s - loss: 0.3150 - accuracy: 0.8694 - val_loss: 0.2163 - val_accuracy: 0.9000 - 41ms/epoch - 20ms/step
# Epoch 16/100
# 2/2 - 0s - loss: 0.3130 - accuracy: 0.8694 - val_loss: 0.2120 - val_accuracy: 0.9000 - 27ms/epoch - 14ms/step
# Epoch 17/100
# 2/2 - 0s - loss: 0.3039 - accuracy: 0.8583 - val_loss: 0.2086 - val_accuracy: 0.9000 - 34ms/epoch - 17ms/step
# Epoch 18/100
# 2/2 - 0s - loss: 0.3038 - accuracy: 0.8722 - val_loss: 0.2060 - val_accuracy: 0.9000 - 33ms/epoch - 16ms/step
# Epoch 19/100
# 2/2 - 0s - loss: 0.2966 - accuracy: 0.8722 - val_loss: 0.2035 - val_accuracy: 0.9000 - 31ms/epoch - 15ms/step
# Epoch 20/100
# 2/2 - 0s - loss: 0.2870 - accuracy: 0.8806 - val_loss: 0.2011 - val_accuracy: 0.9000 - 35ms/epoch - 17ms/step
# Epoch 21/100
# 2/2 - 0s - loss: 0.2903 - accuracy: 0.8778 - val_loss: 0.1983 - val_accuracy: 0.9000 - 34ms/epoch - 17ms/step
# Epoch 22/100
# 2/2 - 0s - loss: 0.2921 - accuracy: 0.8667 - val_loss: 0.1950 - val_accuracy: 0.9000 - 34ms/epoch - 17ms/step
# Epoch 23/100
# 2/2 - 0s - loss: 0.2810 - accuracy: 0.8806 - val_loss: 0.1914 - val_accuracy: 0.9000 - 34ms/epoch - 17ms/step
# Epoch 24/100
# 2/2 - 0s - loss: 0.2878 - accuracy: 0.8778 - val_loss: 0.1880 - val_accuracy: 0.9000 - 37ms/epoch - 18ms/step
# Epoch 25/100
# 2/2 - 0s - loss: 0.2630 - accuracy: 0.8889 - val_loss: 0.1844 - val_accuracy: 0.9000 - 32ms/epoch - 16ms/step
# Epoch 26/100
# 2/2 - 0s - loss: 0.2659 - accuracy: 0.8889 - val_loss: 0.1798 - val_accuracy: 0.9000 - 32ms/epoch - 16ms/step
# Epoch 27/100
# 2/2 - 0s - loss: 0.2716 - accuracy: 0.8889 - val_loss: 0.1758 - val_accuracy: 0.9000 - 37ms/epoch - 18ms/step
# Epoch 28/100
# 2/2 - 0s - loss: 0.2705 - accuracy: 0.8806 - val_loss: 0.1719 - val_accuracy: 0.9250 - 36ms/epoch - 18ms/step
# Epoch 29/100
# 2/2 - 0s - loss: 0.2603 - accuracy: 0.8778 - val_loss: 0.1675 - val_accuracy: 0.9250 - 34ms/epoch - 17ms/step
# Epoch 30/100
# 2/2 - 0s - loss: 0.2476 - accuracy: 0.8972 - val_loss: 0.1632 - val_accuracy: 0.9250 - 37ms/epoch - 19ms/step
# Epoch 31/100
# 2/2 - 0s - loss: 0.2480 - accuracy: 0.9083 - val_loss: 0.1594 - val_accuracy: 0.9500 - 51ms/epoch - 26ms/step
# Epoch 32/100
# 2/2 - 0s - loss: 0.2469 - accuracy: 0.9028 - val_loss: 0.1555 - val_accuracy: 0.9500 - 39ms/epoch - 20ms/step
# Epoch 33/100
# 2/2 - 0s - loss: 0.2511 - accuracy: 0.9028 - val_loss: 0.1529 - val_accuracy: 0.9250 - 36ms/epoch - 18ms/step
# Epoch 34/100
# 2/2 - 0s - loss: 0.2440 - accuracy: 0.8889 - val_loss: 0.1514 - val_accuracy: 0.9250 - 37ms/epoch - 18ms/step
# Epoch 35/100
# 2/2 - 0s - loss: 0.2389 - accuracy: 0.8972 - val_loss: 0.1463 - val_accuracy: 0.9500 - 34ms/epoch - 17ms/step
# Epoch 36/100
# 2/2 - 0s - loss: 0.2354 - accuracy: 0.8944 - val_loss: 0.1423 - val_accuracy: 0.9500 - 35ms/epoch - 17ms/step
# Epoch 37/100
# 2/2 - 0s - loss: 0.2298 - accuracy: 0.9056 - val_loss: 0.1392 - val_accuracy: 0.9500 - 36ms/epoch - 18ms/step
# Epoch 38/100
# 2/2 - 0s - loss: 0.2298 - accuracy: 0.8944 - val_loss: 0.1370 - val_accuracy: 0.9500 - 38ms/epoch - 19ms/step
# Epoch 39/100
# 2/2 - 0s - loss: 0.2193 - accuracy: 0.9056 - val_loss: 0.1352 - val_accuracy: 0.9500 - 38ms/epoch - 19ms/step
# Epoch 40/100
# 2/2 - 0s - loss: 0.2290 - accuracy: 0.8972 - val_loss: 0.1313 - val_accuracy: 0.9750 - 32ms/epoch - 16ms/step
# Epoch 41/100
# 2/2 - 0s - loss: 0.2157 - accuracy: 0.9000 - val_loss: 0.1282 - val_accuracy: 0.9750 - 32ms/epoch - 16ms/step
# Epoch 42/100
# 2/2 - 0s - loss: 0.2221 - accuracy: 0.9000 - val_loss: 0.1250 - val_accuracy: 0.9750 - 43ms/epoch - 21ms/step
# Epoch 43/100
# 2/2 - 0s - loss: 0.2049 - accuracy: 0.9194 - val_loss: 0.1228 - val_accuracy: 0.9750 - 36ms/epoch - 18ms/step
# Epoch 44/100
# 2/2 - 0s - loss: 0.2078 - accuracy: 0.9139 - val_loss: 0.1211 - val_accuracy: 0.9750 - 29ms/epoch - 15ms/step
# Epoch 45/100
# 2/2 - 0s - loss: 0.1944 - accuracy: 0.9139 - val_loss: 0.1172 - val_accuracy: 0.9750 - 33ms/epoch - 17ms/step
# Epoch 46/100
# 2/2 - 0s - loss: 0.2099 - accuracy: 0.9056 - val_loss: 0.1149 - val_accuracy: 0.9750 - 32ms/epoch - 16ms/step
# Epoch 47/100
# 2/2 - 0s - loss: 0.1980 - accuracy: 0.9250 - val_loss: 0.1122 - val_accuracy: 0.9750 - 46ms/epoch - 23ms/step
# Epoch 48/100
# 2/2 - 0s - loss: 0.2052 - accuracy: 0.9111 - val_loss: 0.1101 - val_accuracy: 0.9750 - 33ms/epoch - 16ms/step
# Epoch 49/100
# 2/2 - 0s - loss: 0.1947 - accuracy: 0.9306 - val_loss: 0.1077 - val_accuracy: 0.9750 - 32ms/epoch - 16ms/step
# Epoch 50/100
# 2/2 - 0s - loss: 0.1983 - accuracy: 0.9194 - val_loss: 0.1061 - val_accuracy: 0.9750 - 39ms/epoch - 20ms/step
# Epoch 51/100
# 2/2 - 0s - loss: 0.1977 - accuracy: 0.9194 - val_loss: 0.1046 - val_accuracy: 0.9750 - 46ms/epoch - 23ms/step
# Epoch 52/100
# 2/2 - 0s - loss: 0.1891 - accuracy: 0.9222 - val_loss: 0.1012 - val_accuracy: 0.9750 - 36ms/epoch - 18ms/step
# Epoch 53/100
# 2/2 - 0s - loss: 0.1942 - accuracy: 0.9194 - val_loss: 0.0994 - val_accuracy: 0.9750 - 39ms/epoch - 19ms/step
# Epoch 54/100
# 2/2 - 0s - loss: 0.1898 - accuracy: 0.9250 - val_loss: 0.0966 - val_accuracy: 0.9750 - 34ms/epoch - 17ms/step
# Epoch 55/100
# 2/2 - 0s - loss: 0.1858 - accuracy: 0.9250 - val_loss: 0.0949 - val_accuracy: 0.9750 - 45ms/epoch - 23ms/step
# Epoch 56/100
# 2/2 - 0s - loss: 0.1786 - accuracy: 0.9333 - val_loss: 0.0926 - val_accuracy: 0.9750 - 34ms/epoch - 17ms/step
# Epoch 57/100
# 2/2 - 0s - loss: 0.1752 - accuracy: 0.9361 - val_loss: 0.0898 - val_accuracy: 0.9750 - 33ms/epoch - 17ms/step
# Epoch 58/100
# 2/2 - 0s - loss: 0.1808 - accuracy: 0.9222 - val_loss: 0.0879 - val_accuracy: 0.9750 - 37ms/epoch - 19ms/step
# Epoch 59/100
# 2/2 - 0s - loss: 0.1696 - accuracy: 0.9389 - val_loss: 0.0876 - val_accuracy: 0.9750 - 32ms/epoch - 16ms/step
# Epoch 60/100
# 2/2 - 0s - loss: 0.1928 - accuracy: 0.9111 - val_loss: 0.0879 - val_accuracy: 0.9750 - 36ms/epoch - 18ms/step
# Epoch 61/100
# 2/2 - 0s - loss: 0.1823 - accuracy: 0.9278 - val_loss: 0.0839 - val_accuracy: 0.9750 - 36ms/epoch - 18ms/step
# Epoch 62/100
# 2/2 - 0s - loss: 0.1713 - accuracy: 0.9333 - val_loss: 0.0835 - val_accuracy: 0.9750 - 33ms/epoch - 17ms/step
# Epoch 63/100
# 2/2 - 0s - loss: 0.1783 - accuracy: 0.9306 - val_loss: 0.0787 - val_accuracy: 0.9750 - 36ms/epoch - 18ms/step
# Epoch 64/100
# 2/2 - 0s - loss: 0.1861 - accuracy: 0.9222 - val_loss: 0.0783 - val_accuracy: 0.9750 - 35ms/epoch - 18ms/step
# Epoch 65/100
# 2/2 - 0s - loss: 0.1663 - accuracy: 0.9278 - val_loss: 0.0763 - val_accuracy: 0.9750 - 31ms/epoch - 16ms/step
# Epoch 66/100
# 2/2 - 0s - loss: 0.1767 - accuracy: 0.9278 - val_loss: 0.0754 - val_accuracy: 0.9750 - 52ms/epoch - 26ms/step
# Epoch 67/100
# 2/2 - 0s - loss: 0.1808 - accuracy: 0.9278 - val_loss: 0.0753 - val_accuracy: 0.9750 - 39ms/epoch - 20ms/step
# Epoch 68/100
# 2/2 - 0s - loss: 0.1734 - accuracy: 0.9222 - val_loss: 0.0748 - val_accuracy: 0.9750 - 31ms/epoch - 16ms/step
# Epoch 69/100
# 2/2 - 0s - loss: 0.1781 - accuracy: 0.9306 - val_loss: 0.0735 - val_accuracy: 0.9750 - 32ms/epoch - 16ms/step
# Epoch 70/100
# 2/2 - 0s - loss: 0.1768 - accuracy: 0.9278 - val_loss: 0.0722 - val_accuracy: 0.9750 - 35ms/epoch - 17ms/step
# Epoch 71/100
# 2/2 - 0s - loss: 0.1686 - accuracy: 0.9278 - val_loss: 0.0720 - val_accuracy: 0.9750 - 29ms/epoch - 15ms/step
# Epoch 72/100
# 2/2 - 0s - loss: 0.1668 - accuracy: 0.9389 - val_loss: 0.0713 - val_accuracy: 0.9750 - 36ms/epoch - 18ms/step
# Epoch 73/100
# 2/2 - 0s - loss: 0.1747 - accuracy: 0.9306 - val_loss: 0.0697 - val_accuracy: 0.9750 - 33ms/epoch - 17ms/step
# Epoch 74/100
# 2/2 - 0s - loss: 0.1649 - accuracy: 0.9444 - val_loss: 0.0700 - val_accuracy: 0.9750 - 44ms/epoch - 22ms/step
# Epoch 75/100
# 2/2 - 0s - loss: 0.1593 - accuracy: 0.9389 - val_loss: 0.0692 - val_accuracy: 0.9750 - 41ms/epoch - 21ms/step
# Epoch 76/100
# 2/2 - 0s - loss: 0.1747 - accuracy: 0.9250 - val_loss: 0.0680 - val_accuracy: 0.9750 - 36ms/epoch - 18ms/step
# Epoch 77/100
# 2/2 - 0s - loss: 0.1531 - accuracy: 0.9333 - val_loss: 0.0675 - val_accuracy: 0.9750 - 33ms/epoch - 16ms/step
# Epoch 78/100
# 2/2 - 0s - loss: 0.1659 - accuracy: 0.9361 - val_loss: 0.0652 - val_accuracy: 0.9750 - 32ms/epoch - 16ms/step
# Epoch 79/100
# 2/2 - 0s - loss: 0.1635 - accuracy: 0.9333 - val_loss: 0.0646 - val_accuracy: 0.9750 - 30ms/epoch - 15ms/step
# Epoch 80/100
# 2/2 - 0s - loss: 0.1671 - accuracy: 0.9306 - val_loss: 0.0639 - val_accuracy: 0.9750 - 44ms/epoch - 22ms/step
# Epoch 81/100
# 2/2 - 0s - loss: 0.1566 - accuracy: 0.9417 - val_loss: 0.0647 - val_accuracy: 0.9750 - 40ms/epoch - 20ms/step
# Epoch 82/100
# 2/2 - 0s - loss: 0.1527 - accuracy: 0.9389 - val_loss: 0.0645 - val_accuracy: 0.9750 - 41ms/epoch - 20ms/step
# Epoch 83/100
# 2/2 - 0s - loss: 0.1619 - accuracy: 0.9389 - val_loss: 0.0654 - val_accuracy: 0.9750 - 33ms/epoch - 16ms/step
# Epoch 84/100
# 2/2 - 0s - loss: 0.1649 - accuracy: 0.9250 - val_loss: 0.0653 - val_accuracy: 0.9750 - 36ms/epoch - 18ms/step
# Epoch 85/100
# 2/2 - 0s - loss: 0.1671 - accuracy: 0.9389 - val_loss: 0.0632 - val_accuracy: 0.9750 - 40ms/epoch - 20ms/step
# Epoch 86/100
# 2/2 - 0s - loss: 0.1600 - accuracy: 0.9306 - val_loss: 0.0636 - val_accuracy: 0.9750 - 36ms/epoch - 18ms/step
# Epoch 87/100
# 2/2 - 0s - loss: 0.1679 - accuracy: 0.9306 - val_loss: 0.0618 - val_accuracy: 0.9750 - 45ms/epoch - 23ms/step
# Epoch 88/100
# 2/2 - 0s - loss: 0.1671 - accuracy: 0.9250 - val_loss: 0.0654 - val_accuracy: 0.9750 - 51ms/epoch - 25ms/step
# Epoch 89/100
# 2/2 - 0s - loss: 0.1608 - accuracy: 0.9389 - val_loss: 0.0616 - val_accuracy: 0.9750 - 44ms/epoch - 22ms/step
# Epoch 90/100
# 2/2 - 0s - loss: 0.1571 - accuracy: 0.9333 - val_loss: 0.0630 - val_accuracy: 0.9750 - 34ms/epoch - 17ms/step
# Epoch 91/100
# 2/2 - 0s - loss: 0.1654 - accuracy: 0.9278 - val_loss: 0.0633 - val_accuracy: 0.9750 - 42ms/epoch - 21ms/step
# Epoch 92/100
# 2/2 - 0s - loss: 0.1452 - accuracy: 0.9389 - val_loss: 0.0641 - val_accuracy: 0.9750 - 35ms/epoch - 17ms/step
# Epoch 93/100
# 2/2 - 0s - loss: 0.1744 - accuracy: 0.9278 - val_loss: 0.0641 - val_accuracy: 0.9750 - 33ms/epoch - 16ms/step
# Epoch 94/100
# 2/2 - 0s - loss: 0.1617 - accuracy: 0.9361 - val_loss: 0.0622 - val_accuracy: 0.9750 - 49ms/epoch - 24ms/step
# Epoch 95/100
# 2/2 - 0s - loss: 0.1620 - accuracy: 0.9361 - val_loss: 0.0611 - val_accuracy: 0.9750 - 45ms/epoch - 23ms/step
# Epoch 96/100
# 2/2 - 0s - loss: 0.1714 - accuracy: 0.9306 - val_loss: 0.0611 - val_accuracy: 0.9750 - 42ms/epoch - 21ms/step
# Epoch 97/100
# 2/2 - 0s - loss: 0.1629 - accuracy: 0.9250 - val_loss: 0.0605 - val_accuracy: 0.9750 - 42ms/epoch - 21ms/step
# Epoch 98/100
# 2/2 - 0s - loss: 0.1676 - accuracy: 0.9278 - val_loss: 0.0580 - val_accuracy: 0.9750 - 35ms/epoch - 18ms/step
# Epoch 99/100
# 2/2 - 0s - loss: 0.1655 - accuracy: 0.9222 - val_loss: 0.0572 - val_accuracy: 0.9750 - 33ms/epoch - 16ms/step
# Epoch 100/100
# 2/2 - 0s - loss: 0.1630 - accuracy: 0.9389 - val_loss: 0.0574 - val_accuracy: 0.9750 - 37ms/epoch - 18ms/step

# %%
plt.plot(history_2.history['accuracy'])
plt.plot(history_2.history['val_accuracy'])
plt.title('Accuracy vs Epochs')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='lower right')
plt.show()

# %% [markdown]
# **Observations**
#
# - We are able to improve the model performance on the training data - accuracy has increased by only ~0.3% but the validation accuracy is has increased by 2.5%.
# - The validation accuracy is higher than the training accuracy. This might due to the small size of the validation set and the model is able is to correctly classify the data points in the validation set.

# %% [markdown]
# Let's try to further tune some of the hyper-parameters and check if we can improve the model performance.
#
# We will use learning_rate = 0.001 for the optimizer in the training process and increase the model complexity by further increasing the number of layers, the number of nodes in each layer, and the epochs.

# %%
#Clearing backend
from tensorflow.keras import backend
backend.clear_session()

# %%
#Fixing the seed for random number generators
np.random.seed(42)
import random
random.seed(42)
tf.random.set_seed(42)

# %%
model_3 = Sequential()

model_3.add(Dense(256, activation='tanh', input_shape=(11,)))
model_3.add(Dropout(0.1))
model_3.add(Dense(128, activation='tanh'))
model_3.add(Dropout(0.1))
model_3.add(Dense(64, activation='tanh'))
model_3.add(Dropout(0.1))
model_3.add(Dense(32, activation='tanh'))
model_3.add(Dense(1, activation='sigmoid'))

# %%
model_3.compile(loss = 'binary_crossentropy', optimizer=tf.keras.optimizers.Adam(learning_rate=0.001), metrics=['accuracy'])
model_3.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 256)               3072
#
#  dropout (Dropout)           (None, 256)               0
#
#  dense_1 (Dense)             (None, 128)               32896
#
#  dropout_1 (Dropout)         (None, 128)               0
#
#  dense_2 (Dense)             (None, 64)                8256
#
#  dropout_2 (Dropout)         (None, 64)                0
#
#  dense_3 (Dense)             (None, 32)                2080
#
#  dense_4 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 46,337
# Trainable params: 46,337
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# - Notice that the number of trainable parameters has increased substantially as compared to previous models.

# %%
history_3 = model_3.fit(X_train_normalized, 
                    y_train, 
                    validation_split=0.1, 
                    epochs=200,
                    verbose=2)
# Out:
# Epoch 1/200
# 12/12 - 1s - loss: 0.4583 - accuracy: 0.8056 - val_loss: 0.2612 - val_accuracy: 0.8750 - 953ms/epoch - 79ms/step
# Epoch 2/200
# 12/12 - 0s - loss: 0.3399 - accuracy: 0.8611 - val_loss: 0.2387 - val_accuracy: 0.9250 - 71ms/epoch - 6ms/step
# Epoch 3/200
# 12/12 - 0s - loss: 0.2994 - accuracy: 0.8778 - val_loss: 0.2106 - val_accuracy: 0.9250 - 77ms/epoch - 6ms/step
# Epoch 4/200
# 12/12 - 0s - loss: 0.2858 - accuracy: 0.8944 - val_loss: 0.1977 - val_accuracy: 0.8750 - 70ms/epoch - 6ms/step
# Epoch 5/200
# 12/12 - 0s - loss: 0.2749 - accuracy: 0.8917 - val_loss: 0.1480 - val_accuracy: 0.9500 - 71ms/epoch - 6ms/step
# Epoch 6/200
# 12/12 - 0s - loss: 0.2608 - accuracy: 0.8972 - val_loss: 0.1420 - val_accuracy: 0.9250 - 82ms/epoch - 7ms/step
# Epoch 7/200
# 12/12 - 0s - loss: 0.2386 - accuracy: 0.8972 - val_loss: 0.1256 - val_accuracy: 0.9750 - 69ms/epoch - 6ms/step
# Epoch 8/200
# 12/12 - 0s - loss: 0.2374 - accuracy: 0.8917 - val_loss: 0.1190 - val_accuracy: 0.9500 - 71ms/epoch - 6ms/step
# Epoch 9/200
# 12/12 - 0s - loss: 0.2233 - accuracy: 0.8944 - val_loss: 0.1199 - val_accuracy: 0.9750 - 77ms/epoch - 6ms/step
# Epoch 10/200
# 12/12 - 0s - loss: 0.2272 - accuracy: 0.9000 - val_loss: 0.1043 - val_accuracy: 1.0000 - 68ms/epoch - 6ms/step
# Epoch 11/200
# 12/12 - 0s - loss: 0.2171 - accuracy: 0.9056 - val_loss: 0.0913 - val_accuracy: 0.9750 - 69ms/epoch - 6ms/step
# Epoch 12/200
# 12/12 - 0s - loss: 0.2254 - accuracy: 0.9083 - val_loss: 0.1635 - val_accuracy: 0.8750 - 73ms/epoch - 6ms/step
# Epoch 13/200
# 12/12 - 0s - loss: 0.2531 - accuracy: 0.8722 - val_loss: 0.1251 - val_accuracy: 0.9250 - 76ms/epoch - 6ms/step
# Epoch 14/200
# 12/12 - 0s - loss: 0.1954 - accuracy: 0.9139 - val_loss: 0.0968 - val_accuracy: 0.9750 - 75ms/epoch - 6ms/step
# Epoch 15/200
# 12/12 - 0s - loss: 0.1971 - accuracy: 0.9111 - val_loss: 0.0805 - val_accuracy: 0.9750 - 71ms/epoch - 6ms/step
# Epoch 16/200
# 12/12 - 0s - loss: 0.1815 - accuracy: 0.9194 - val_loss: 0.0736 - val_accuracy: 1.0000 - 67ms/epoch - 6ms/step
# Epoch 17/200
# 12/12 - 0s - loss: 0.1702 - accuracy: 0.9250 - val_loss: 0.0849 - val_accuracy: 0.9750 - 72ms/epoch - 6ms/step
# Epoch 18/200
# 12/12 - 0s - loss: 0.1669 - accuracy: 0.9306 - val_loss: 0.0670 - val_accuracy: 0.9750 - 81ms/epoch - 7ms/step
# Epoch 19/200
# 12/12 - 0s - loss: 0.1799 - accuracy: 0.9333 - val_loss: 0.0613 - val_accuracy: 0.9750 - 79ms/epoch - 7ms/step
# Epoch 20/200
# 12/12 - 0s - loss: 0.2018 - accuracy: 0.9194 - val_loss: 0.0870 - val_accuracy: 0.9750 - 68ms/epoch - 6ms/step
# Epoch 21/200
# 12/12 - 0s - loss: 0.1842 - accuracy: 0.9361 - val_loss: 0.0750 - val_accuracy: 0.9750 - 71ms/epoch - 6ms/step
# Epoch 22/200
# 12/12 - 0s - loss: 0.1533 - accuracy: 0.9528 - val_loss: 0.0684 - val_accuracy: 1.0000 - 80ms/epoch - 7ms/step
# Epoch 23/200
# 12/12 - 0s - loss: 0.1883 - accuracy: 0.9250 - val_loss: 0.0568 - val_accuracy: 1.0000 - 66ms/epoch - 6ms/step
# Epoch 24/200
# 12/12 - 0s - loss: 0.1782 - accuracy: 0.9361 - val_loss: 0.0704 - val_accuracy: 0.9750 - 66ms/epoch - 6ms/step
# Epoch 25/200
# 12/12 - 0s - loss: 0.1765 - accuracy: 0.9250 - val_loss: 0.0533 - val_accuracy: 1.0000 - 70ms/epoch - 6ms/step
# Epoch 26/200
# 12/12 - 0s - loss: 0.1890 - accuracy: 0.9167 - val_loss: 0.0709 - val_accuracy: 0.9750 - 68ms/epoch - 6ms/step
# Epoch 27/200
# 12/12 - 0s - loss: 0.1877 - accuracy: 0.9250 - val_loss: 0.0599 - val_accuracy: 0.9750 - 70ms/epoch - 6ms/step
# Epoch 28/200
# 12/12 - 0s - loss: 0.1716 - accuracy: 0.9389 - val_loss: 0.0542 - val_accuracy: 1.0000 - 70ms/epoch - 6ms/step
# Epoch 29/200
# 12/12 - 0s - loss: 0.1666 - accuracy: 0.9250 - val_loss: 0.0693 - val_accuracy: 0.9750 - 66ms/epoch - 5ms/step
# Epoch 30/200
# 12/12 - 0s - loss: 0.1628 - accuracy: 0.9306 - val_loss: 0.0472 - val_accuracy: 1.0000 - 71ms/epoch - 6ms/step
# Epoch 31/200
# 12/12 - 0s - loss: 0.1592 - accuracy: 0.9417 - val_loss: 0.0542 - val_accuracy: 0.9750 - 69ms/epoch - 6ms/step
# Epoch 32/200
# 12/12 - 0s - loss: 0.1797 - accuracy: 0.9167 - val_loss: 0.0593 - val_accuracy: 1.0000 - 83ms/epoch - 7ms/step
# Epoch 33/200
# 12/12 - 0s - loss: 0.1564 - accuracy: 0.9333 - val_loss: 0.0504 - val_accuracy: 1.0000 - 77ms/epoch - 6ms/step
# Epoch 34/200
# 12/12 - 0s - loss: 0.1725 - accuracy: 0.9278 - val_loss: 0.0701 - val_accuracy: 0.9750 - 72ms/epoch - 6ms/step
# Epoch 35/200
# 12/12 - 0s - loss: 0.1788 - accuracy: 0.9194 - val_loss: 0.0681 - val_accuracy: 1.0000 - 67ms/epoch - 6ms/step
# Epoch 36/200
# 12/12 - 0s - loss: 0.1606 - accuracy: 0.9417 - val_loss: 0.0573 - val_accuracy: 0.9750 - 70ms/epoch - 6ms/step
# Epoch 37/200
# 12/12 - 0s - loss: 0.1555 - accuracy: 0.9417 - val_loss: 0.0599 - val_accuracy: 1.0000 - 70ms/epoch - 6ms/step
# Epoch 38/200
# 12/12 - 0s - loss: 0.1540 - accuracy: 0.9278 - val_loss: 0.0552 - val_accuracy: 1.0000 - 73ms/epoch - 6ms/step
# Epoch 39/200
# 12/12 - 0s - loss: 0.1607 - accuracy: 0.9278 - val_loss: 0.0590 - val_accuracy: 0.9750 - 67ms/epoch - 6ms/step
# Epoch 40/200
# 12/12 - 0s - loss: 0.1543 - accuracy: 0.9222 - val_loss: 0.0749 - val_accuracy: 0.9750 - 71ms/epoch - 6ms/step
# Epoch 41/200
# 12/12 - 0s - loss: 0.1589 - accuracy: 0.9222 - val_loss: 0.0493 - val_accuracy: 1.0000 - 70ms/epoch - 6ms/step
# Epoch 42/200
# 12/12 - 0s - loss: 0.1697 - accuracy: 0.9194 - val_loss: 0.0613 - val_accuracy: 1.0000 - 79ms/epoch - 7ms/step
# Epoch 43/200
# 12/12 - 0s - loss: 0.1908 - accuracy: 0.9056 - val_loss: 0.0688 - val_accuracy: 0.9500 - 69ms/epoch - 6ms/step
# Epoch 44/200
# 12/12 - 0s - loss: 0.1707 - accuracy: 0.9250 - val_loss: 0.0731 - val_accuracy: 1.0000 - 66ms/epoch - 6ms/step
# Epoch 45/200
# 12/12 - 0s - loss: 0.1634 - accuracy: 0.9306 - val_loss: 0.0652 - val_accuracy: 1.0000 - 69ms/epoch - 6ms/step
# Epoch 46/200
# 12/12 - 0s - loss: 0.1716 - accuracy: 0.9306 - val_loss: 0.0717 - val_accuracy: 0.9750 - 83ms/epoch - 7ms/step
# Epoch 47/200
# 12/12 - 0s - loss: 0.1547 - accuracy: 0.9361 - val_loss: 0.0785 - val_accuracy: 0.9750 - 71ms/epoch - 6ms/step
# Epoch 48/200
# 12/12 - 0s - loss: 0.1704 - accuracy: 0.9167 - val_loss: 0.0574 - val_accuracy: 0.9750 - 68ms/epoch - 6ms/step
# Epoch 49/200
# 12/12 - 0s - loss: 0.1560 - accuracy: 0.9306 - val_loss: 0.0452 - val_accuracy: 1.0000 - 66ms/epoch - 6ms/step
# Epoch 50/200
# 12/12 - 0s - loss: 0.1563 - accuracy: 0.9361 - val_loss: 0.0455 - val_accuracy: 1.0000 - 73ms/epoch - 6ms/step
# Epoch 51/200
# 12/12 - 0s - loss: 0.1461 - accuracy: 0.9417 - val_loss: 0.0730 - val_accuracy: 0.9750 - 72ms/epoch - 6ms/step
# Epoch 52/200
# 12/12 - 0s - loss: 0.1728 - accuracy: 0.9306 - val_loss: 0.0700 - val_accuracy: 0.9750 - 66ms/epoch - 6ms/step
# Epoch 53/200
# 12/12 - 0s - loss: 0.1472 - accuracy: 0.9389 - val_loss: 0.0557 - val_accuracy: 1.0000 - 72ms/epoch - 6ms/step
# Epoch 54/200
# 12/12 - 0s - loss: 0.1405 - accuracy: 0.9389 - val_loss: 0.0487 - val_accuracy: 1.0000 - 73ms/epoch - 6ms/step
# Epoch 55/200
# 12/12 - 0s - loss: 0.1508 - accuracy: 0.9306 - val_loss: 0.0471 - val_accuracy: 0.9750 - 70ms/epoch - 6ms/step
# Epoch 56/200
# 12/12 - 0s - loss: 0.1389 - accuracy: 0.9500 - val_loss: 0.0426 - val_accuracy: 1.0000 - 66ms/epoch - 5ms/step
# Epoch 57/200
# 12/12 - 0s - loss: 0.1404 - accuracy: 0.9444 - val_loss: 0.0519 - val_accuracy: 1.0000 - 68ms/epoch - 6ms/step
# Epoch 58/200
# 12/12 - 0s - loss: 0.1507 - accuracy: 0.9278 - val_loss: 0.1059 - val_accuracy: 0.9500 - 68ms/epoch - 6ms/step
# Epoch 59/200
# 12/12 - 0s - loss: 0.1790 - accuracy: 0.9194 - val_loss: 0.0470 - val_accuracy: 1.0000 - 103ms/epoch - 9ms/step
# Epoch 60/200
# 12/12 - 0s - loss: 0.1732 - accuracy: 0.9111 - val_loss: 0.0570 - val_accuracy: 1.0000 - 68ms/epoch - 6ms/step
# Epoch 61/200
# 12/12 - 0s - loss: 0.1576 - accuracy: 0.9278 - val_loss: 0.0819 - val_accuracy: 0.9500 - 74ms/epoch - 6ms/step
# Epoch 62/200
# 12/12 - 0s - loss: 0.1576 - accuracy: 0.9250 - val_loss: 0.0522 - val_accuracy: 1.0000 - 68ms/epoch - 6ms/step
# Epoch 63/200
# 12/12 - 0s - loss: 0.1440 - accuracy: 0.9444 - val_loss: 0.0520 - val_accuracy: 1.0000 - 68ms/epoch - 6ms/step
# Epoch 64/200
# 12/12 - 0s - loss: 0.1303 - accuracy: 0.9361 - val_loss: 0.0502 - val_accuracy: 1.0000 - 68ms/epoch - 6ms/step
# Epoch 65/200
# 12/12 - 0s - loss: 0.1509 - accuracy: 0.9306 - val_loss: 0.0791 - val_accuracy: 0.9500 - 77ms/epoch - 6ms/step
# Epoch 66/200
# 12/12 - 0s - loss: 0.1431 - accuracy: 0.9444 - val_loss: 0.0375 - val_accuracy: 1.0000 - 70ms/epoch - 6ms/step
# Epoch 67/200
# 12/12 - 0s - loss: 0.1347 - accuracy: 0.9417 - val_loss: 0.0429 - val_accuracy: 1.0000 - 66ms/epoch - 6ms/step
# Epoch 68/200
# 12/12 - 0s - loss: 0.1420 - accuracy: 0.9389 - val_loss: 0.0505 - val_accuracy: 1.0000 - 71ms/epoch - 6ms/step
# Epoch 69/200
# 12/12 - 0s - loss: 0.1457 - accuracy: 0.9278 - val_loss: 0.0409 - val_accuracy: 1.0000 - 68ms/epoch - 6ms/step
# Epoch 70/200
# 12/12 - 0s - loss: 0.1459 - accuracy: 0.9333 - val_loss: 0.0480 - val_accuracy: 0.9750 - 76ms/epoch - 6ms/step
# Epoch 71/200
# 12/12 - 0s - loss: 0.1354 - accuracy: 0.9389 - val_loss: 0.0389 - val_accuracy: 1.0000 - 73ms/epoch - 6ms/step
# Epoch 72/200
# 12/12 - 0s - loss: 0.1393 - accuracy: 0.9417 - val_loss: 0.0548 - val_accuracy: 0.9750 - 82ms/epoch - 7ms/step
# Epoch 73/200
# 12/12 - 0s - loss: 0.1443 - accuracy: 0.9306 - val_loss: 0.0431 - val_accuracy: 1.0000 - 72ms/epoch - 6ms/step
# Epoch 74/200
# 12/12 - 0s - loss: 0.1230 - accuracy: 0.9472 - val_loss: 0.0622 - val_accuracy: 0.9750 - 67ms/epoch - 6ms/step
# Epoch 75/200
# 12/12 - 0s - loss: 0.1304 - accuracy: 0.9417 - val_loss: 0.0353 - val_accuracy: 1.0000 - 69ms/epoch - 6ms/step
# Epoch 76/200
# 12/12 - 0s - loss: 0.1385 - accuracy: 0.9444 - val_loss: 0.0444 - val_accuracy: 0.9750 - 87ms/epoch - 7ms/step
# Epoch 77/200
# 12/12 - 0s - loss: 0.1388 - accuracy: 0.9389 - val_loss: 0.0552 - val_accuracy: 0.9750 - 70ms/epoch - 6ms/step
# Epoch 78/200
# 12/12 - 0s - loss: 0.1391 - accuracy: 0.9444 - val_loss: 0.0351 - val_accuracy: 1.0000 - 71ms/epoch - 6ms/step
# Epoch 79/200
# 12/12 - 0s - loss: 0.1236 - accuracy: 0.9500 - val_loss: 0.0403 - val_accuracy: 1.0000 - 66ms/epoch - 6ms/step
# Epoch 80/200
# 12/12 - 0s - loss: 0.1354 - accuracy: 0.9389 - val_loss: 0.0688 - val_accuracy: 0.9500 - 65ms/epoch - 5ms/step
# Epoch 81/200
# 12/12 - 0s - loss: 0.1201 - accuracy: 0.9444 - val_loss: 0.0419 - val_accuracy: 0.9750 - 77ms/epoch - 6ms/step
# Epoch 82/200
# 12/12 - 0s - loss: 0.1314 - accuracy: 0.9472 - val_loss: 0.0493 - val_accuracy: 0.9750 - 70ms/epoch - 6ms/step
# Epoch 83/200
# 12/12 - 0s - loss: 0.1250 - accuracy: 0.9472 - val_loss: 0.0575 - val_accuracy: 0.9750 - 67ms/epoch - 6ms/step
# Epoch 84/200
# 12/12 - 0s - loss: 0.1301 - accuracy: 0.9333 - val_loss: 0.0559 - val_accuracy: 0.9750 - 68ms/epoch - 6ms/step
# Epoch 85/200
# 12/12 - 0s - loss: 0.1217 - accuracy: 0.9528 - val_loss: 0.0411 - val_accuracy: 0.9750 - 71ms/epoch - 6ms/step
# Epoch 86/200
# 12/12 - 0s - loss: 0.1219 - accuracy: 0.9583 - val_loss: 0.0527 - val_accuracy: 0.9750 - 76ms/epoch - 6ms/step
# Epoch 87/200
# 12/12 - 0s - loss: 0.1228 - accuracy: 0.9500 - val_loss: 0.0729 - val_accuracy: 0.9750 - 69ms/epoch - 6ms/step
# Epoch 88/200
# 12/12 - 0s - loss: 0.1188 - accuracy: 0.9472 - val_loss: 0.0478 - val_accuracy: 0.9750 - 66ms/epoch - 6ms/step
# Epoch 89/200
# 12/12 - 0s - loss: 0.1206 - accuracy: 0.9417 - val_loss: 0.0370 - val_accuracy: 1.0000 - 72ms/epoch - 6ms/step
# Epoch 90/200
# 12/12 - 0s - loss: 0.1265 - accuracy: 0.9417 - val_loss: 0.0552 - val_accuracy: 0.9750 - 69ms/epoch - 6ms/step
# Epoch 91/200
# 12/12 - 0s - loss: 0.1304 - accuracy: 0.9389 - val_loss: 0.0461 - val_accuracy: 0.9750 - 68ms/epoch - 6ms/step
# Epoch 92/200
# 12/12 - 0s - loss: 0.1327 - accuracy: 0.9361 - val_loss: 0.0486 - val_accuracy: 0.9750 - 68ms/epoch - 6ms/step
# Epoch 93/200
# 12/12 - 0s - loss: 0.1253 - accuracy: 0.9500 - val_loss: 0.0612 - val_accuracy: 0.9750 - 74ms/epoch - 6ms/step
# Epoch 94/200
# 12/12 - 0s - loss: 0.1365 - accuracy: 0.9389 - val_loss: 0.0458 - val_accuracy: 1.0000 - 76ms/epoch - 6ms/step
# Epoch 95/200
# 12/12 - 0s - loss: 0.1296 - accuracy: 0.9444 - val_loss: 0.0627 - val_accuracy: 0.9750 - 76ms/epoch - 6ms/step
# Epoch 96/200
# 12/12 - 0s - loss: 0.1168 - accuracy: 0.9556 - val_loss: 0.0524 - val_accuracy: 0.9750 - 77ms/epoch - 6ms/step
# Epoch 97/200
# 12/12 - 0s - loss: 0.1111 - accuracy: 0.9472 - val_loss: 0.0501 - val_accuracy: 0.9750 - 75ms/epoch - 6ms/step
# Epoch 98/200
# 12/12 - 0s - loss: 0.1299 - accuracy: 0.9472 - val_loss: 0.0614 - val_accuracy: 0.9750 - 78ms/epoch - 7ms/step
# Epoch 99/200
# 12/12 - 0s - loss: 0.1144 - accuracy: 0.9500 - val_loss: 0.0433 - val_accuracy: 0.9750 - 87ms/epoch - 7ms/step
# Epoch 100/200
# 12/12 - 0s - loss: 0.1169 - accuracy: 0.9389 - val_loss: 0.0365 - val_accuracy: 1.0000 - 75ms/epoch - 6ms/step
# Epoch 101/200
# 12/12 - 0s - loss: 0.1370 - accuracy: 0.9389 - val_loss: 0.0859 - val_accuracy: 0.9500 - 71ms/epoch - 6ms/step
# Epoch 102/200
# 12/12 - 0s - loss: 0.1298 - accuracy: 0.9389 - val_loss: 0.0718 - val_accuracy: 0.9750 - 69ms/epoch - 6ms/step
# Epoch 103/200
# 12/12 - 0s - loss: 0.1221 - accuracy: 0.9444 - val_loss: 0.0604 - val_accuracy: 0.9750 - 86ms/epoch - 7ms/step
# Epoch 104/200
# 12/12 - 0s - loss: 0.1554 - accuracy: 0.9278 - val_loss: 0.0794 - val_accuracy: 0.9500 - 76ms/epoch - 6ms/step
# Epoch 105/200
# 12/12 - 0s - loss: 0.1188 - accuracy: 0.9472 - val_loss: 0.0396 - val_accuracy: 1.0000 - 71ms/epoch - 6ms/step
# Epoch 106/200
# 12/12 - 0s - loss: 0.1175 - accuracy: 0.9472 - val_loss: 0.1318 - val_accuracy: 0.9500 - 71ms/epoch - 6ms/step
# Epoch 107/200
# 12/12 - 0s - loss: 0.1474 - accuracy: 0.9361 - val_loss: 0.0504 - val_accuracy: 0.9750 - 66ms/epoch - 6ms/step
# Epoch 108/200
# 12/12 - 0s - loss: 0.1216 - accuracy: 0.9528 - val_loss: 0.0393 - val_accuracy: 1.0000 - 76ms/epoch - 6ms/step
# Epoch 109/200
# 12/12 - 0s - loss: 0.1353 - accuracy: 0.9361 - val_loss: 0.1135 - val_accuracy: 0.9500 - 74ms/epoch - 6ms/step
# Epoch 110/200
# 12/12 - 0s - loss: 0.1128 - accuracy: 0.9556 - val_loss: 0.0370 - val_accuracy: 1.0000 - 67ms/epoch - 6ms/step
# Epoch 111/200
# 12/12 - 0s - loss: 0.1131 - accuracy: 0.9528 - val_loss: 0.0885 - val_accuracy: 0.9500 - 70ms/epoch - 6ms/step
# Epoch 112/200
# 12/12 - 0s - loss: 0.1248 - accuracy: 0.9500 - val_loss: 0.0346 - val_accuracy: 1.0000 - 83ms/epoch - 7ms/step
# Epoch 113/200
# 12/12 - 0s - loss: 0.1114 - accuracy: 0.9417 - val_loss: 0.0865 - val_accuracy: 0.9750 - 68ms/epoch - 6ms/step
# Epoch 114/200
# 12/12 - 0s - loss: 0.1282 - accuracy: 0.9333 - val_loss: 0.0790 - val_accuracy: 0.9750 - 70ms/epoch - 6ms/step
# Epoch 115/200
# 12/12 - 0s - loss: 0.1228 - accuracy: 0.9472 - val_loss: 0.0411 - val_accuracy: 0.9750 - 72ms/epoch - 6ms/step
# Epoch 116/200
# 12/12 - 0s - loss: 0.1088 - accuracy: 0.9639 - val_loss: 0.0700 - val_accuracy: 0.9750 - 70ms/epoch - 6ms/step
# Epoch 117/200
# 12/12 - 0s - loss: 0.1097 - accuracy: 0.9611 - val_loss: 0.0595 - val_accuracy: 0.9750 - 76ms/epoch - 6ms/step
# Epoch 118/200
# 12/12 - 0s - loss: 0.1203 - accuracy: 0.9472 - val_loss: 0.0467 - val_accuracy: 0.9750 - 72ms/epoch - 6ms/step
# Epoch 119/200
# 12/12 - 0s - loss: 0.1166 - accuracy: 0.9444 - val_loss: 0.0665 - val_accuracy: 0.9750 - 76ms/epoch - 6ms/step
# Epoch 120/200
# 12/12 - 0s - loss: 0.1082 - accuracy: 0.9556 - val_loss: 0.0658 - val_accuracy: 0.9750 - 72ms/epoch - 6ms/step
# Epoch 121/200
# 12/12 - 0s - loss: 0.1146 - accuracy: 0.9472 - val_loss: 0.0592 - val_accuracy: 0.9750 - 71ms/epoch - 6ms/step
# Epoch 122/200
# 12/12 - 0s - loss: 0.1026 - accuracy: 0.9583 - val_loss: 0.0653 - val_accuracy: 0.9750 - 76ms/epoch - 6ms/step
# Epoch 123/200
# 12/12 - 0s - loss: 0.1175 - accuracy: 0.9500 - val_loss: 0.0471 - val_accuracy: 0.9750 - 70ms/epoch - 6ms/step
# Epoch 124/200
# 12/12 - 0s - loss: 0.1343 - accuracy: 0.9417 - val_loss: 0.1277 - val_accuracy: 0.9500 - 68ms/epoch - 6ms/step
# Epoch 125/200
# 12/12 - 0s - loss: 0.1256 - accuracy: 0.9444 - val_loss: 0.0361 - val_accuracy: 0.9750 - 79ms/epoch - 7ms/step
# Epoch 126/200
# 12/12 - 0s - loss: 0.1292 - accuracy: 0.9472 - val_loss: 0.0542 - val_accuracy: 0.9750 - 72ms/epoch - 6ms/step
# Epoch 127/200
# 12/12 - 0s - loss: 0.1197 - accuracy: 0.9528 - val_loss: 0.0540 - val_accuracy: 0.9750 - 75ms/epoch - 6ms/step
# Epoch 128/200
# 12/12 - 0s - loss: 0.1528 - accuracy: 0.9417 - val_loss: 0.1072 - val_accuracy: 0.9500 - 68ms/epoch - 6ms/step
# Epoch 129/200
# 12/12 - 0s - loss: 0.1241 - accuracy: 0.9444 - val_loss: 0.0596 - val_accuracy: 0.9750 - 71ms/epoch - 6ms/step
# Epoch 130/200
# 12/12 - 0s - loss: 0.1201 - accuracy: 0.9444 - val_loss: 0.0565 - val_accuracy: 0.9750 - 72ms/epoch - 6ms/step
# Epoch 131/200
# 12/12 - 0s - loss: 0.1274 - accuracy: 0.9500 - val_loss: 0.0769 - val_accuracy: 0.9750 - 74ms/epoch - 6ms/step
# Epoch 132/200
# 12/12 - 0s - loss: 0.1062 - accuracy: 0.9444 - val_loss: 0.0608 - val_accuracy: 0.9750 - 71ms/epoch - 6ms/step
# Epoch 133/200
# 12/12 - 0s - loss: 0.1043 - accuracy: 0.9583 - val_loss: 0.0503 - val_accuracy: 0.9750 - 73ms/epoch - 6ms/step
# Epoch 134/200
# 12/12 - 0s - loss: 0.1037 - accuracy: 0.9528 - val_loss: 0.0612 - val_accuracy: 0.9750 - 75ms/epoch - 6ms/step
# Epoch 135/200
# 12/12 - 0s - loss: 0.1117 - accuracy: 0.9444 - val_loss: 0.0488 - val_accuracy: 0.9750 - 76ms/epoch - 6ms/step
# Epoch 136/200
# 12/12 - 0s - loss: 0.1069 - accuracy: 0.9583 - val_loss: 0.0932 - val_accuracy: 0.9750 - 73ms/epoch - 6ms/step
# Epoch 137/200
# 12/12 - 0s - loss: 0.1110 - accuracy: 0.9611 - val_loss: 0.0595 - val_accuracy: 0.9750 - 72ms/epoch - 6ms/step
# Epoch 138/200
# 12/12 - 0s - loss: 0.1027 - accuracy: 0.9500 - val_loss: 0.0538 - val_accuracy: 0.9750 - 86ms/epoch - 7ms/step
# Epoch 139/200
# 12/12 - 0s - loss: 0.0988 - accuracy: 0.9639 - val_loss: 0.0467 - val_accuracy: 0.9750 - 70ms/epoch - 6ms/step
# Epoch 140/200
# 12/12 - 0s - loss: 0.1109 - accuracy: 0.9583 - val_loss: 0.0275 - val_accuracy: 1.0000 - 69ms/epoch - 6ms/step
# Epoch 141/200
# 12/12 - 0s - loss: 0.1002 - accuracy: 0.9556 - val_loss: 0.0679 - val_accuracy: 0.9750 - 71ms/epoch - 6ms/step
# Epoch 142/200
# 12/12 - 0s - loss: 0.1180 - accuracy: 0.9500 - val_loss: 0.0395 - val_accuracy: 0.9750 - 76ms/epoch - 6ms/step
# Epoch 143/200
# 12/12 - 0s - loss: 0.1180 - accuracy: 0.9472 - val_loss: 0.0814 - val_accuracy: 0.9750 - 72ms/epoch - 6ms/step
# Epoch 144/200
# 12/12 - 0s - loss: 0.1150 - accuracy: 0.9417 - val_loss: 0.0609 - val_accuracy: 0.9750 - 68ms/epoch - 6ms/step
# Epoch 145/200
# 12/12 - 0s - loss: 0.1108 - accuracy: 0.9528 - val_loss: 0.0547 - val_accuracy: 0.9500 - 68ms/epoch - 6ms/step
# Epoch 146/200
# 12/12 - 0s - loss: 0.1372 - accuracy: 0.9472 - val_loss: 0.0393 - val_accuracy: 1.0000 - 73ms/epoch - 6ms/step
# Epoch 147/200
# 12/12 - 0s - loss: 0.1040 - accuracy: 0.9583 - val_loss: 0.0988 - val_accuracy: 0.9500 - 68ms/epoch - 6ms/step
# Epoch 148/200
# 12/12 - 0s - loss: 0.1316 - accuracy: 0.9417 - val_loss: 0.0399 - val_accuracy: 1.0000 - 69ms/epoch - 6ms/step
# Epoch 149/200
# 12/12 - 0s - loss: 0.1689 - accuracy: 0.9389 - val_loss: 0.1305 - val_accuracy: 0.9500 - 67ms/epoch - 6ms/step
# Epoch 150/200
# 12/12 - 0s - loss: 0.1417 - accuracy: 0.9361 - val_loss: 0.0907 - val_accuracy: 0.9750 - 77ms/epoch - 6ms/step
# Epoch 151/200
# 12/12 - 0s - loss: 0.1005 - accuracy: 0.9500 - val_loss: 0.0981 - val_accuracy: 0.9750 - 79ms/epoch - 7ms/step
# Epoch 152/200
# 12/12 - 0s - loss: 0.1052 - accuracy: 0.9583 - val_loss: 0.0498 - val_accuracy: 0.9750 - 68ms/epoch - 6ms/step
# Epoch 153/200
# 12/12 - 0s - loss: 0.0979 - accuracy: 0.9611 - val_loss: 0.0876 - val_accuracy: 0.9750 - 73ms/epoch - 6ms/step
# Epoch 154/200
# 12/12 - 0s - loss: 0.1040 - accuracy: 0.9583 - val_loss: 0.0541 - val_accuracy: 0.9750 - 82ms/epoch - 7ms/step
# Epoch 155/200
# 12/12 - 0s - loss: 0.1030 - accuracy: 0.9472 - val_loss: 0.0609 - val_accuracy: 0.9750 - 68ms/epoch - 6ms/step
# Epoch 156/200
# 12/12 - 0s - loss: 0.1048 - accuracy: 0.9556 - val_loss: 0.0982 - val_accuracy: 0.9750 - 67ms/epoch - 6ms/step
# Epoch 157/200
# 12/12 - 0s - loss: 0.0960 - accuracy: 0.9611 - val_loss: 0.0742 - val_accuracy: 0.9750 - 69ms/epoch - 6ms/step
# Epoch 158/200
# 12/12 - 0s - loss: 0.1075 - accuracy: 0.9556 - val_loss: 0.0574 - val_accuracy: 0.9750 - 80ms/epoch - 7ms/step
# Epoch 159/200
# 12/12 - 0s - loss: 0.0921 - accuracy: 0.9639 - val_loss: 0.0751 - val_accuracy: 0.9750 - 68ms/epoch - 6ms/step
# Epoch 160/200
# 12/12 - 0s - loss: 0.0935 - accuracy: 0.9611 - val_loss: 0.0616 - val_accuracy: 0.9750 - 70ms/epoch - 6ms/step
# Epoch 161/200
# 12/12 - 0s - loss: 0.1123 - accuracy: 0.9500 - val_loss: 0.0664 - val_accuracy: 0.9750 - 103ms/epoch - 9ms/step
# Epoch 162/200
# 12/12 - 0s - loss: 0.0937 - accuracy: 0.9639 - val_loss: 0.0644 - val_accuracy: 0.9750 - 166ms/epoch - 14ms/step
# Epoch 163/200
# 12/12 - 0s - loss: 0.1012 - accuracy: 0.9667 - val_loss: 0.0517 - val_accuracy: 0.9750 - 160ms/epoch - 13ms/step
# Epoch 164/200
# 12/12 - 0s - loss: 0.1011 - accuracy: 0.9583 - val_loss: 0.1395 - val_accuracy: 0.9500 - 99ms/epoch - 8ms/step
# Epoch 165/200
# 12/12 - 0s - loss: 0.1156 - accuracy: 0.9556 - val_loss: 0.0368 - val_accuracy: 0.9750 - 67ms/epoch - 6ms/step
# Epoch 166/200
# 12/12 - 0s - loss: 0.1047 - accuracy: 0.9528 - val_loss: 0.0781 - val_accuracy: 0.9750 - 79ms/epoch - 7ms/step
# Epoch 167/200
# 12/12 - 0s - loss: 0.1155 - accuracy: 0.9389 - val_loss: 0.0778 - val_accuracy: 0.9500 - 71ms/epoch - 6ms/step
# Epoch 168/200
# 12/12 - 0s - loss: 0.0962 - accuracy: 0.9500 - val_loss: 0.0603 - val_accuracy: 0.9750 - 71ms/epoch - 6ms/step
# Epoch 169/200
# 12/12 - 0s - loss: 0.1206 - accuracy: 0.9500 - val_loss: 0.0557 - val_accuracy: 0.9750 - 70ms/epoch - 6ms/step
# Epoch 170/200
# 12/12 - 0s - loss: 0.1544 - accuracy: 0.9389 - val_loss: 0.0784 - val_accuracy: 0.9750 - 79ms/epoch - 7ms/step
# Epoch 171/200
# 12/12 - 0s - loss: 0.1334 - accuracy: 0.9444 - val_loss: 0.1414 - val_accuracy: 0.9500 - 71ms/epoch - 6ms/step
# Epoch 172/200
# 12/12 - 0s - loss: 0.1111 - accuracy: 0.9556 - val_loss: 0.0864 - val_accuracy: 0.9750 - 73ms/epoch - 6ms/step
# Epoch 173/200
# 12/12 - 0s - loss: 0.0958 - accuracy: 0.9528 - val_loss: 0.0566 - val_accuracy: 0.9750 - 67ms/epoch - 6ms/step
# Epoch 174/200
# 12/12 - 0s - loss: 0.1068 - accuracy: 0.9528 - val_loss: 0.0452 - val_accuracy: 0.9750 - 84ms/epoch - 7ms/step
# Epoch 175/200
# 12/12 - 0s - loss: 0.1097 - accuracy: 0.9500 - val_loss: 0.0892 - val_accuracy: 0.9750 - 70ms/epoch - 6ms/step
# Epoch 176/200
# 12/12 - 0s - loss: 0.1123 - accuracy: 0.9583 - val_loss: 0.1208 - val_accuracy: 0.9750 - 74ms/epoch - 6ms/step
# Epoch 177/200
# 12/12 - 0s - loss: 0.1149 - accuracy: 0.9472 - val_loss: 0.0741 - val_accuracy: 0.9750 - 75ms/epoch - 6ms/step
# Epoch 178/200
# 12/12 - 0s - loss: 0.0994 - accuracy: 0.9500 - val_loss: 0.1273 - val_accuracy: 0.9500 - 73ms/epoch - 6ms/step
# Epoch 179/200
# 12/12 - 0s - loss: 0.0904 - accuracy: 0.9556 - val_loss: 0.0559 - val_accuracy: 0.9750 - 74ms/epoch - 6ms/step
# Epoch 180/200
# 12/12 - 0s - loss: 0.0933 - accuracy: 0.9639 - val_loss: 0.0640 - val_accuracy: 0.9750 - 70ms/epoch - 6ms/step
# Epoch 181/200
# 12/12 - 0s - loss: 0.1011 - accuracy: 0.9500 - val_loss: 0.0606 - val_accuracy: 0.9750 - 82ms/epoch - 7ms/step
# Epoch 182/200
# 12/12 - 0s - loss: 0.1334 - accuracy: 0.9472 - val_loss: 0.0982 - val_accuracy: 0.9500 - 68ms/epoch - 6ms/step
# Epoch 183/200
# 12/12 - 0s - loss: 0.1197 - accuracy: 0.9444 - val_loss: 0.1034 - val_accuracy: 0.9750 - 71ms/epoch - 6ms/step
# Epoch 184/200
# 12/12 - 0s - loss: 0.0974 - accuracy: 0.9639 - val_loss: 0.1028 - val_accuracy: 0.9750 - 73ms/epoch - 6ms/step
# Epoch 185/200
# 12/12 - 0s - loss: 0.0957 - accuracy: 0.9667 - val_loss: 0.0434 - val_accuracy: 0.9750 - 76ms/epoch - 6ms/step
# Epoch 186/200
# 12/12 - 0s - loss: 0.0960 - accuracy: 0.9583 - val_loss: 0.0406 - val_accuracy: 0.9750 - 73ms/epoch - 6ms/step
# Epoch 187/200
# 12/12 - 0s - loss: 0.1170 - accuracy: 0.9500 - val_loss: 0.0493 - val_accuracy: 0.9750 - 88ms/epoch - 7ms/step
# Epoch 188/200
# 12/12 - 0s - loss: 0.1055 - accuracy: 0.9556 - val_loss: 0.0523 - val_accuracy: 0.9750 - 89ms/epoch - 7ms/step
# Epoch 189/200
# 12/12 - 0s - loss: 0.0912 - accuracy: 0.9611 - val_loss: 0.0935 - val_accuracy: 0.9750 - 73ms/epoch - 6ms/step
# Epoch 190/200
# 12/12 - 0s - loss: 0.0914 - accuracy: 0.9667 - val_loss: 0.0737 - val_accuracy: 0.9750 - 70ms/epoch - 6ms/step
# Epoch 191/200
# 12/12 - 0s - loss: 0.1007 - accuracy: 0.9556 - val_loss: 0.0851 - val_accuracy: 0.9750 - 71ms/epoch - 6ms/step
# Epoch 192/200
# 12/12 - 0s - loss: 0.0911 - accuracy: 0.9667 - val_loss: 0.0749 - val_accuracy: 0.9750 - 74ms/epoch - 6ms/step
# Epoch 193/200
# 12/12 - 0s - loss: 0.0994 - accuracy: 0.9472 - val_loss: 0.0820 - val_accuracy: 0.9750 - 72ms/epoch - 6ms/step
# Epoch 194/200
# 12/12 - 0s - loss: 0.1111 - accuracy: 0.9500 - val_loss: 0.0481 - val_accuracy: 1.0000 - 73ms/epoch - 6ms/step
# Epoch 195/200
# 12/12 - 0s - loss: 0.1452 - accuracy: 0.9417 - val_loss: 0.1230 - val_accuracy: 0.9500 - 75ms/epoch - 6ms/step
# Epoch 196/200
# 12/12 - 0s - loss: 0.1523 - accuracy: 0.9389 - val_loss: 0.0697 - val_accuracy: 0.9750 - 73ms/epoch - 6ms/step
# Epoch 197/200
# 12/12 - 0s - loss: 0.0986 - accuracy: 0.9639 - val_loss: 0.1095 - val_accuracy: 0.9750 - 70ms/epoch - 6ms/step
# Epoch 198/200
# 12/12 - 0s - loss: 0.1271 - accuracy: 0.9472 - val_loss: 0.1318 - val_accuracy: 0.9500 - 70ms/epoch - 6ms/step
# Epoch 199/200
# 12/12 - 0s - loss: 0.1361 - accuracy: 0.9417 - val_loss: 0.0593 - val_accuracy: 0.9750 - 71ms/epoch - 6ms/step
# Epoch 200/200
# 12/12 - 0s - loss: 0.1009 - accuracy: 0.9583 - val_loss: 0.0582 - val_accuracy: 0.9750 - 86ms/epoch - 7ms/step

# %%
plt.plot(history_3.history['accuracy'])
plt.plot(history_3.history['val_accuracy'])
plt.title('Accuracy vs Epochs')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='lower right')
plt.show()

# %% [markdown]
# - This model is giving a generalized performance with 95% accuracy on the train as well as validation data.
# - The validation accuracy is the same as the previous model but the training accuracy has increased by ~1.4%.
# - One reason for the algorithm not being able to reach higher than 95% even for training data might be due to the optimizer being stuck at some local minima.
# - One way to resolve that is to further tune the model with some other hyper-parameters.
# - Among all three models, model 3 has given the best performance. Let's check its performance on the test data.

# %% [markdown]
# ### **Model evaluation on the test data**

# %%
model_3.evaluate(X_test_normalized, y_test, verbose = 1)
test_pred = np.round(model_3.predict(X_test_normalized))
# Out:
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1904 - accuracy: 0.9200

# %% [markdown]
# The test accuracy is also coming out to be 95% which implies that our model is able to replicate the performance from the train and validation data on the test (unseen) data.

# %%
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
print(classification_report(y_test, test_pred))
cm = confusion_matrix(y_test, test_pred)
plt.figure(figsize=(8,5))
sns.heatmap(cm, annot=True,  fmt='.0f', xticklabels=['Admitted', 'Not Admitted'], yticklabels=['Admitted', 'Not Admitted'])
plt.ylabel('Actual')
plt.xlabel('Predicted')
plt.show()
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      0.96      0.95        72
#            1       0.88      0.82      0.85        28
#
#     accuracy                           0.92       100
#    macro avg       0.91      0.89      0.90       100
# weighted avg       0.92      0.92      0.92       100

# %% [markdown]
# - The confusion matrix shows that the model can identify the majority of students who would get admission and who won't get admission into UCLA.
# - The classification report shows that all the metrics except recall for class 1 are above 90% which is good.

# %% [markdown]
# ### **Conclusion**

# %% [markdown]
# In this case study,
# - We have learned how to build a feed-forward neural network for a classification task using Keras.
# - We have seen different hyper-parameters and how they affect the network.
# - We have also learned about the accuracy vs epoch curve and how it helps to understand the model is learning the weights.
# - We were able to get the test accuracy of 95% using the final model.
# - Interested learners can further analyze those 5 misclassified points and see if there is a pattern or if they were outliers that our model could not identify.
# - We would highly recommend you to play around with the other hyper-parameter and see for yourself how it affects your model.

# %% [markdown]
# Hyperparameter Tuning using Keras Tuner RandomizedSearchCV# New Section

# %% [markdown]
# Reference article for Hyperparameter Tuning
#
# https://www.analyticsvidhya.com/blog/2021/06/tuning-hyperparameters-of-an-artificial-neural-network-leveraging-keras-tuner/

# %%
def build_model(hp):
    model_1 = Sequential() #Start model
    model_1.add(Dense(units=hp.Int('units_in',min_value=16,max_value=256,step=32),  
                    input_shape = (11,), 
                    activation = hp.Choice('act_in', ['relu', 'tanh']))) # Hidden Layer connected to Input Layer
    for i in range(hp.Int('num_layers', 0, 2)):
      model_1.add(Dense(units=hp.Int('units_' + str(i),
                                            min_value=32,
                                            max_value=512,
                                            step=32),
                               activation=hp.Choice('act_' + str(i), ['relu','leakyrelu', 'tanh'])))  # Hidden Layer
      model_1.add(Dropout(hp.Float('dropout', 0, 0.5, step=0.1, default=0.3))) # Drop out layer for regularization

    model_1.add(Dense(1, activation='sigmoid')) # Output layer
      
    model_1.compile(
         optimizer=optimizers.Adam(
             hp.Choice('learning_rate', [1e-2, 1e-3, 1e-4])),
             loss='binary_crossentropy',
             metrics=['accuracy'])
      
    return model_1

# %%
#Make sure you are in right directory to save Hyperparameter tuner results
cd /content/drive/MyDrive/GL_MIT/
# Out:
# /content/drive/MyDrive/GL_MIT

# %%
ls

# %%
tuner = RandomSearch(
    build_model,
    objective='val_accuracy',
    max_trials=5,
    executions_per_trial=3,
    directory='Acad_Dir',
    project_name='Acad_Proj')

# %%
tuner.search_space_summary()
# Out:
# Search space summary
# Default search space size: 4
# units_in (Int)
# {'default': None, 'conditions': [], 'min_value': 16, 'max_value': 256, 'step': 32, 'sampling': None}
# act_in (Choice)
# {'default': 'relu', 'conditions': [], 'values': ['relu', 'tanh'], 'ordered': False}
# num_layers (Int)
# {'default': None, 'conditions': [], 'min_value': 0, 'max_value': 2, 'step': 1, 'sampling': None}
# learning_rate (Choice)
# {'default': 0.01, 'conditions': [], 'values': [0.01, 0.001, 0.0001], 'ordered': True}

# %%
tuner.search(X_train_normalized, y_train , epochs = 10,validation_split=0.1)
# Out:
# Trial 5 Complete [00h 00m 06s]
# val_accuracy: 1.0
#
# Best val_accuracy So Far: 1.0
# Total elapsed time: 00h 00m 32s
# INFO:tensorflow:Oracle triggered exit

# %%
#Summary of best results
print(tuner.results_summary())
# Out:
# Results summary
# Results in Acad_Dir/Acad_Proj
# Showing 10 best trials
# Objective(name='val_accuracy', direction='max')
# Trial summary
# Hyperparameters:
# units_in: 240
# act_in: tanh
# num_layers: 1
# learning_rate: 0.01
# units_0: 224
# act_0: relu
# dropout: 0.1
# Score: 1.0
# Trial summary
# Hyperparameters:
# units_in: 80
# act_in: relu
# num_layers: 1
# learning_rate: 0.001
# units_0: 320
# act_0: relu
# dropout: 0.2
# Score: 0.9666666587193807
# Trial summary
# Hyperparameters:
# units_in: 176
# act_in: tanh
# num_layers: 1
# learning_rate: 0.0001
# units_0: 224
# act_0: relu
# dropout: 0.1
# Score: 0.8999999761581421
# Trial summary
# Hyperparameters:
# units_in: 112
# act_in: tanh
# num_layers: 1
# learning_rate: 0.0001
# units_0: 192
# act_0: tanh
# dropout: 0.0
# Score: 0.8916666507720947
# Trial summary
# Hyperparameters:
# units_in: 48
# act_in: relu
# num_layers: 1
# learning_rate: 0.0001
# units_0: 32
# act_0: relu
# dropout: 0.3
# Score: 0.7333333492279053
# None

# %%
# Best Hyperparameter model using Randomized Search CV - This can change on individual machines
print(tuner.get_best_hyperparameters()[0].values)
# Out:
# {'units_in': 240, 'act_in': 'tanh', 'num_layers': 1, 'learning_rate': 0.01, 'units_0': 224, 'act_0': 'relu', 'dropout': 0.1}

# %%
print(tuner.get_best_models()[0].summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 240)               2880
#
#  dense_1 (Dense)             (None, 224)               53984
#
#  dropout (Dropout)           (None, 224)               0
#
#  dense_2 (Dense)             (None, 1)                 225
#
# =================================================================
# Total params: 57,089
# Trainable params: 57,089
# Non-trainable params: 0
# _________________________________________________________________
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.iter
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.beta_1
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.beta_2
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.decay
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.learning_rate
# WARNING:tensorflow:A checkpoint was restored (e.g. tf.train.Checkpoint.restore or tf.keras.Model.load_weights) but not all checkpointed values were used. See above for specific issues. Use expect_partial() on the load status object, e.g. tf.train.Checkpoint.restore(...).expect_partial(), to silence these warnings, or use assert_consumed() to make the check explicit. See https://www.tensorflow.org/guide/checkpoint#loading_mechanics for details.
# None

# %%
# Run test data against best Hyperparametrized Model
best_model = tuner.get_best_models(num_models=1)[0]
results = best_model.evaluate(X_test_normalized, y_test, verbose = 1)
# Out:
# 4/4 [==============================] - 0s 6ms/step - loss: 0.2129 - accuracy: 0.9200

# %%
#Best Model plot
plot_model(best_model, to_file='best_model_plot.png', show_shapes=True, show_layer_names=True)
